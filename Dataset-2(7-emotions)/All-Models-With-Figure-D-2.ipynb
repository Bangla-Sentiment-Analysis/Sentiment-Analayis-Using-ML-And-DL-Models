# %%
#Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install bnlp_toolkit
# !pip install bnltk
# !pip install -U bnlp_toolkit
# Out:
# Collecting bnltk
#   Downloading bnltk-0.7.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting black==24.10.0 (from bnltk)
#   Downloading black-24.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 3.2 MB/s eta 0:00:00
# Collecting keras==3.6.0 (from bnltk)
#   Downloading keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy==2.0.2 (from bnltk)
#   Downloading numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from bnltk) (2.32.3)
# Collecting scikit-learn==1.5.2 (from bnltk)
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: tensorflow==2.18.0 in /usr/local/lib/python3.11/dist-packages (from bnltk) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black==24.10.0->bnltk) (8.1.8)
# Collecting mypy-extensions>=0.4.3 (from black==24.10.0->bnltk)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.11/dist-packages (from black==24.10.0->bnltk) (24.2)
# Collecting pathspec>=0.9.0 (from black==24.10.0->bnltk)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black==24.10.0->bnltk) (4.3.6)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras==3.6.0->bnltk) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras==3.6.0->bnltk) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras==3.6.0->bnltk) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras==3.6.0->bnltk) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras==3.6.0->bnltk) (0.14.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras==3.6.0->bnltk) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->bnltk) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->bnltk) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->bnltk) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->bnltk) (2025.1.31)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2->bnltk) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2->bnltk) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2->bnltk) (3.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->bnltk) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.18.0->bnltk) (0.45.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->bnltk) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->bnltk) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->bnltk) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras==3.6.0->bnltk) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras==3.6.0->bnltk) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.6.0->bnltk) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow==2.18.0->bnltk) (3.0.2)
# Downloading bnltk-0.7.8-py3-none-any.whl (15 kB)
# Downloading black-24.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.8 MB/s eta 0:00:00
# Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.4 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 85.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 91.8 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Installing collected packages: pathspec, numpy, mypy-extensions, black, scikit-learn, keras, bnltk
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
#     Uninstalling keras-3.8.0:
#       Successfully uninstalled keras-3.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.0.2 which is incompatible.
# pytensor 2.27.1 requires numpy<2,>=1.17.0, but you have numpy 2.0.2 which is incompatible.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 2.0.2 which is incompatible.
# Successfully installed black-24.10.0 bnltk-0.7.8 keras-3.6.0 mypy-extensions-1.0.0 numpy-2.0.2 pathspec-0.12.1 scikit-learn-1.5.2
# Collecting bnlp_toolkit
#   Downloading bnlp_toolkit-4.0.3-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.11/dist-packages (from bnlp_toolkit) (0.2.0)
# Collecting gensim==4.3.2 (from bnlp_toolkit)
#   Downloading gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from bnlp_toolkit) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from bnlp_toolkit) (2.0.2)
# Collecting scipy==1.10.1 (from bnlp_toolkit)
#   Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 3.8 MB/s eta 0:00:00
# Collecting sklearn-crfsuite==0.3.6 (from bnlp_toolkit)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting tqdm==4.66.3 (from bnlp_toolkit)
#   Downloading tqdm-4.66.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.1 MB/s eta 0:00:00
# Collecting ftfy==6.2.0 (from bnlp_toolkit)
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting emoji==1.7.0 (from bnlp_toolkit)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from bnlp_toolkit) (2.32.3)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.11/dist-packages (from ftfy==6.2.0->bnlp_toolkit) (0.2.13)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim==4.3.2->bnlp_toolkit) (7.1.0)
# Collecting numpy (from bnlp_toolkit)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.7 MB/s eta 0:00:00
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite==0.3.6->bnlp_toolkit)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite==0.3.6->bnlp_toolkit) (1.17.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite==0.3.6->bnlp_toolkit) (0.9.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->bnlp_toolkit) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->bnlp_toolkit) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->bnlp_toolkit) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->bnlp_toolkit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->bnlp_toolkit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->bnlp_toolkit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->bnlp_toolkit) (2025.1.31)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim==4.3.2->bnlp_toolkit) (1.17.2)
# Downloading bnlp_toolkit-4.0.3-py3-none-any.whl (22 kB)
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 5.7 MB/s eta 0:00:00
# Downloading gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 79.7 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 17.7 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Downloading tqdm-4.66.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 7.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 103.8 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.8 MB/s eta 0:00:00
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=8f717d51b6041b5d937066055161c705b8fced4ae806906631abd413c8ff95c8
#   Stored in directory: /root/.cache/pip/wheels/bd/22/e5/b69726d5e1a19795ecd3b3e7464b16c0f1d019aa94ff1c8578
# Successfully built emoji
# Installing collected packages: emoji, tqdm, python-crfsuite, numpy, ftfy, sklearn-crfsuite, scipy, gensim, bnlp_toolkit
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.3
#     Uninstalling gensim-4.3.3:
#       Successfully uninstalled gensim-4.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bnltk 0.7.8 requires numpy==2.0.2, but you have numpy 1.26.4 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.10.1 which is incompatible.
# Successfully installed bnlp_toolkit-4.0.3 emoji-1.7.0 ftfy-6.2.0 gensim-4.3.2 numpy-1.26.4 python-crfsuite-0.9.11 scipy-1.10.1 sklearn-crfsuite-0.3.6 tqdm-4.66.3

# %%
#Import libraries for data cleanning

import re
from bnltk.stemmer import BanglaStemmer
import pandas as pd

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Thesis Model/Dataset-2/dataset-1.xlsx")
df_train = pd.read_csv("/content/drive/MyDrive/Thesis Model/Dataset-2/train.csv")
df_test = pd.read_csv("/content/drive/MyDrive/Thesis Model/Dataset-2/test.csv")
df_val = pd.read_csv("/content/drive/MyDrive/Thesis Model/Dataset-2/val.csv")

print("Train Dataset Label Counts:")
print(df_train['Label'].value_counts())
print("\nTest Dataset Label Counts:")
print(df_test['Label'].value_counts())
print("\nValidation Dataset Label Counts:")
print(df_val['Label'].value_counts())
# Out:
# Train Dataset Label Counts:
# Label
# joy         7669
# sadness     4856
# anger       3435
# love        2277
# surprise     744
# fear         233
# Name: count, dtype: int64
#
# Test Dataset Label Counts:
# Label
# joy         1434
# sadness      991
# anger        730
# love         464
# surprise     150
# fear          67
# Name: count, dtype: int64
#
# Validation Dataset Label Counts:
# Label
# joy         1427
# sadness      855
# anger        620
# love         389
# surprise     137
# fear          32
# Name: count, dtype: int64

# %%
print("df:",df.shape)
print("df_train:",df_train.shape)
print("df_test:",df_test.shape)
print("df_val:",df_val.shape)
# Out:
# df: (13436, 2)
# df_train: (19214, 2)
# df_test: (3836, 2)
# df_val: (3460, 2)

# %%
# prompt: take df and add 1000 to df_val and 1000 to df_test add rest to df_train

# Add 1000 rows from df to df_val
df_val = pd.concat([df_val, df.iloc[:500]], ignore_index=True)

# Add 1000 rows from df to df_test
df_test = pd.concat([df_test, df.iloc[500:1000]], ignore_index=True)

# Add the remaining rows from df to df_train
df_train = pd.concat([df_train, df.iloc[1000:]], ignore_index=True)

print("\nUpdated Train Dataset Label Counts:")
print(df_train['Label'].value_counts())
print("\nUpdated Test Dataset Label Counts:")
print(df_test['Label'].value_counts())
print("\nUpdated Validation Dataset Label Counts:")
print(df_val['Label'].value_counts())
# Out:
# Updated Train Dataset Label Counts:
# Label
# joy         10790
# sadness      7404
# anger        5733
# love         2277
# surprise     2066
# disgust      1817
# fear         1563
# Name: count, dtype: int64
#
# Updated Test Dataset Label Counts:
# Label
# joy         1612
# sadness     1055
# anger        829
# love         464
# surprise     170
# disgust      131
# fear          75
# Name: count, dtype: int64
#
# Updated Validation Dataset Label Counts:
# Label
# joy         1595
# sadness      926
# anger        703
# love         389
# surprise     161
# disgust      131
# fear          55
# Name: count, dtype: int64

# %%
print("df:",df.shape)
print("df_train:",df_train.shape)
print("df_test:",df_test.shape)
print("df_val:",df_val.shape)
# Out:
# df: (13436, 2)
# df_train: (31650, 2)
# df_test: (4336, 2)
# df_val: (3960, 2)

# %% [markdown]
# >**Data cleaning and preprocessing**

# %%
from bnlp import CleanText
# Out:
# punkt not found. downloading...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# from bnlp import CleanText
#Preprocessing Part Starts
clean_text_processor = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=True,
   remove_email=True,
   remove_emoji=True,
   remove_number=True,
   remove_digits=True,
   remove_punct=True,
   replace_with_url="",
   replace_with_email="",
   replace_with_number="",
   replace_with_digit="",
   replace_with_punct = ""
)

# Testing
# input_text = "আমার সোনার বাংলা <html/>"
# clean_text = clean_text_processor(input_text)
# print(clean_text)

df_train['Text'] = df_train['Text'].apply(lambda x: clean_text_processor(x))
df_test['Text'] = df_test['Text'].apply(lambda x: clean_text_processor(x))
df_val['Text'] = df_val['Text'].apply(lambda x: clean_text_processor(x))

# %%
import re

# %%
# Removing english words and numbers and then removing extra spcaes
def remove_extra_spaces_and_english(text):
  # Remove English words and numbers
  text = re.sub(r'[a-zA-Z0-9]', '', text)

  # Remove extra whitespace characters
  text = re.sub(r'\s+', ' ', text).strip()

  return text


# Example usage (assuming df_train, df_test, and df_val are defined):
df_train['Text'] = df_train['Text'].apply(remove_extra_spaces_and_english)
df_test['Text'] = df_test['Text'].apply(remove_extra_spaces_and_english)
df_val['Text'] = df_val['Text'].apply(remove_extra_spaces_and_english)

# %%
#Check if there are any empty cells

def check_empty_text(df):
  return df['Text'].isnull().any()

def check_empty_label(df):
  return df['Label'].isnull().any()
print(check_empty_text(df_train))
print(check_empty_label(df_train))
# Out:
# False
# False

# %%
# For Deleteing rows with empty cells

def drop_empty_rows(df):
    # Drop rows where 'Text' or 'Label' is empty
    df.dropna(subset=['Text', 'Label'], inplace=True)
    return df

df_train = drop_empty_rows(df_train)
df_test = drop_empty_rows(df_test)
df_val = drop_empty_rows(df_val)

print(check_empty_text(df_train))
print(check_empty_label(df_train))
# Out:
# False
# False

# %%
#Checking if there are any sentences with single word in Text Field

def check_single_word_cells(df):
  for index, row in df.iterrows():
    text = row['Text']
    if isinstance(text, str):  # Check if the value is a string
        words = text.split()
        if len(words) == 1 and words[0] != '': #check for empty string after spliting
          return True
  return False

print(check_single_word_cells(df_train))
print(check_single_word_cells(df_test))
print(check_single_word_cells(df_val))
# Out:
# True
# False
# False

# %%
# Stemmer
from bnltk.stemmer import BanglaStemmer
bn_stemmer = BanglaStemmer()
def stem_bengali_text(text):
    return [bn_stemmer.stem(word) for word in text]

df_train['Text'] = df_train['Text'].apply(lambda x: ' '.join(stem_bengali_text(x.split())))
df_test['Text'] = df_test['Text'].apply(lambda x: ' '.join(stem_bengali_text(x.split())))
df_val['Text'] = df_val['Text'].apply(lambda x: ' '.join(stem_bengali_text(x.split())))

print(df_train.head())
print(df_test.head())
print(df_val.head())
# Out:
#                                                 Text    Label
# 0                               লকাল বাস ভালো এ থাকা  sadness
# 1    কত অভিজান  চল কিন্তু ওয়াস পানির অভিজান কর না ক  sadness
# 2  বিয় মহল ছেড় তিনি বিস্রাম নি চল যান নং ছ বিয়...    anger
# 3                           চাচাজি  কেবল মা ধর্ষণ কর  sadness
# 4                               সত্যিক মানুষ তারা ভা      joy
#                                                 Text    Label
# 0                তারা মন কর ব্রো বলা মান ট্রল ক ব্রো    anger
# 1                আর কিছু না কারণ রাগ আড়াল লুকিয় থা    anger
# 2  শালীনতা থাকল ত প্রতি মন থেকে সন্মান জাগ ছোট ভা...      joy
# 3  নতুন ইনকাম এর পথ খুল পদদা সেতু কাজ শেষ কর গিয়...  sadness
# 4  মাদরাস ছাএ  পার বল কোনো কথা না ও কব আব পারেনা ...     love
#                                                 Text    Label
# 0  চট্রগ্রাম এবং কক্সবাজ বন্যা কবলিত এলাকা ত্রান ...      joy
# 1  আম কা ছিল শুধু রিহান ফটো এলবাম বছর দুয়েক পর ট...    anger
# 2                  হারিয় দেখিয় দিলো মাদ্রাসা ছাত্র      joy
# 3         তো বালছিড় কাঙলাচোদ দলছোটলোক ভিখারিচোদ দেশ  sadness
# 4                                 বিপ্লবী সাহসী মেয়      joy

# %%
from bnlp import BengaliCorpus as corpus
#Remove stop words
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word not in corpus.stopwords]
    return " ".join(filtered_words)

df_train['Text'] = df_train['Text'].apply(remove_stopwords)
df_test['Text'] = df_test['Text'].apply(remove_stopwords)
df_val['Text'] = df_val['Text'].apply(remove_stopwords)

# %%
#Check find those texts which are similiar but different in emotion
def find_similar_rows_different_labels(df):


  # Group by 'Text' and check if there are multiple labels for the same text.
  for text, group in df.groupby('Text'):
    if len(group['Label'].unique()) > 1:
      print(f"Similar text '{text}' with different Emotion:")
      print(group[['Text', 'Label']])
      print("-" * 20)

find_similar_rows_different_labels(df_train)
print("------------------")
find_similar_rows_different_labels(df_test)
print("--------------------")
find_similar_rows_different_labels(df_val)
# Out:
# Similar text '' with different Emotion:
#       Text     Label
# 824            anger
# 1517           anger
# 2394             joy
# 3159             joy
# 3176             joy
# 5316        surprise
# 7762             joy
# 8454            love
# 9004            love
# 10654            joy
# 10750            joy
# 12815          anger
# 13175            joy
# 14168            joy
# 18056       surprise
# 18183          anger
# 18876            joy
# 19423        disgust
# 27739        sadness
# 27916       surprise
# 28000            joy
# 28001        sadness
# 28002            joy
# 28210            joy
# 28844        sadness
# 29665       surprise
# 29743            joy
# 29777            joy
# 30253        sadness
# 31143           fear
# --------------------
# Similar text 'অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান অপরাধী এাো বল মোনাফেক কাফ জারজ নাস্তিক আস্তিক মালউন আরো বল' with different Emotion:
#                                                     Text    Label
# 26474  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...    anger
# 26513  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26577  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  disgust
# 26777  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26778  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26779  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26780  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26781  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26782  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26783  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26784  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26785  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26786  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# 26787  অপরাধ কারী অপরাধী প্রশ্রয় দানকারী দুজনে সমান ...  sadness
# --------------------
# Similar text 'অমানুষ' with different Emotion:
#          Text    Label
# 7161   অমানুষ  sadness
# 27867  অমানুষ  disgust
# 27888  অমানুষ    anger
# 27940  অমানুষ  disgust
# --------------------
# Similar text 'অসাধারণ' with different Emotion:
#           Text     Label
# 16765  অসাধারণ       joy
# 28615  অসাধারণ       joy
# 28755  অসাধারণ       joy
# 29719  অসাধারণ  surprise
# 29733  অসাধারণ  surprise
# 30838  অসাধারণ       joy
# --------------------
# Similar text 'অসাধারন' with different Emotion:
#           Text     Label
# 6838   অসাধারন       joy
# 29725  অসাধারন  surprise
# --------------------
# Similar text 'আ' with different Emotion:
#       Text    Label
# 4232     আ      joy
# 4252     আ      joy
# 11506    আ      joy
# 12260    আ      joy
# 15836    আ     fear
# 27944    আ      joy
# 29596    আ  sadness
# --------------------
# Similar text 'আচ্ছা আপনা মিডিয়া জগত মানুষ অন্যায় কর ক নিয় ব বাঁচিয় দ সহকর্মী বল খারাপ ক আপনা আপনা চরিত্র ক' with different Emotion:
#                                                     Text    Label
# 11979  আচ্ছা আপনা মিডিয়া জগত মানুষ অন্যায় কর ক নিয়...  sadness
# 20052  আচ্ছা আপনা মিডিয়া জগত মানুষ অন্যায় কর ক নিয়...    anger
# --------------------
# Similar text 'আন্তর্জাতিক শ্রম সংস্থ আইএল প্রতিষ্ঠ শতবর্ষ পালন উপলক্ষ গিনেস রেকর্ড ভাঙ বাংলাদেশ বিশ্ব সর্ববৃহৎ শার্ট সেলাইয় পরিকল্পনা কর বিশ্ব দ্বিতীয় বৃহত্তম রফতানিকারক বাংলাদেশ পোশাক শিল্প তুল ধর বাংলাদেশ গার্মেন্ট প্রস্তুতকারক রফতানিকারক সমিতি বিজিএমইএ সুতি কাপড় শার্ট সেলাইয় দায়িত্ব দেয়া' with different Emotion:
#                                                     Text     Label
# 20142  আন্তর্জাতিক শ্রম সংস্থ আইএল প্রতিষ্ঠ শতবর্ষ পা...  surprise
# 20143  আন্তর্জাতিক শ্রম সংস্থ আইএল প্রতিষ্ঠ শতবর্ষ পা...       joy
# --------------------
# Similar text 'আব' with different Emotion:
#       Text     Label
# 7220    আব       joy
# 27877   আব  surprise
# --------------------
# Similar text 'আম ছাএ আ আমা ত তাহল আম সিম ব্যবহ কর পার' with different Emotion:
#                                           Text     Label
# 29807  আম ছাএ আ আমা ত তাহল আম সিম ব্যবহ কর পার  surprise
# 29842  আম ছাএ আ আমা ত তাহল আম সিম ব্যবহ কর পার   sadness
# 29862  আম ছাএ আ আমা ত তাহল আম সিম ব্যবহ কর পার   sadness
# --------------------
# Similar text 'আম জানি আপনা কা আম সত্য বাস্তব ঘটনা কখনো আশা আম পাব আপনা সত্য কখনো বল আব বলাটা স্বাভাবিক আপনা মানুষ আপনা সত্য কথা বল বিপদ পড় এরকম অনুষ্ঠান করত মাস খানেক কর পারত কর ক কর করল আপনা সমস্যা হ পার' with different Emotion:
#                                                     Text    Label
# 13058  আম জানি আপনা কা আম সত্য বাস্তব ঘটনা কখনো আশা আ...    anger
# 20252  আম জানি আপনা কা আম সত্য বাস্তব ঘটনা কখনো আশা আ...  sadness
# --------------------
# Similar text 'আম বিচ চা' with different Emotion:
#             Text    Label
# 27799  আম বিচ চা  sadness
# 27861  আম বিচ চা    anger
# --------------------
# Similar text 'আম বোনকাল আপন বোন আপন মেয়েত আরেকজন পালা ভাব চল থাকল আমা বোনেরানেয়ে লেখা কর পারবেনানিরাপদেরাস্তায় চলা ফি কর পারবেনা আসুন সবা মিল প্রতিবাদ করিএর দায়িত্ব কুমিল্লাহ ছাত্র ছাত্রী ভাইবোন আম আপন সকল মন বাংলাদেশ সকল শিক্ষা প্রতিষ্ঠান ছাত্রছাত্রীশিক্ষককর্মচারীঅভিবাবকসচেতন নাগ রিক প্রতিবাদ ক' with different Emotion:
#                                                     Text  Label
# 29326  আম বোনকাল আপন বোন আপন মেয়েত আরেকজন পালা ভাব চ...   fear
# 29376  আম বোনকাল আপন বোন আপন মেয়েত আরেকজন পালা ভাব চ...  anger
# 29381  আম বোনকাল আপন বোন আপন মেয়েত আরেকজন পালা ভাব চ...  anger
# --------------------
# Similar text 'আম ভালো লাগ' with different Emotion:
#              Text Label
# 5128  আম ভালো লাগ  love
# 6825  আম ভালো লাগ   joy
# 6905  আম ভালো লাগ   joy
# --------------------
# Similar text 'আম ম' with different Emotion:
#       Text Label
# 650   আম ম   joy
# 6733  আম ম  love
# --------------------
# Similar text 'আম স্ট্যাটাস বাকি লাইন অস্বীক করবো আগ বিচ অপহরণ চেষ্ খুন এইয ইমাম মুয়াজ্জিন লেখক প্রকাশক ধর্ষণ গুম সন্ত্রাস চাঁদাবাজি কো টাকা লুট' with different Emotion:
#                                                     Text     Label
# 25547  আম স্ট্যাটাস বাকি লাইন অস্বীক করবো আগ বিচ অপহর...     anger
# 25670  আম স্ট্যাটাস বাকি লাইন অস্বীক করবো আগ বিচ অপহর...  surprise
# 25687  আম স্ট্যাটাস বাকি লাইন অস্বীক করবো আগ বিচ অপহর...   sadness
# --------------------
# Similar text 'আয়মান' with different Emotion:
#          Text     Label
# 9194   আয়মান       joy
# 15668  আয়মান  surprise
# --------------------
# Similar text 'আশির দশ আম জন্মে খেয়ে শুনে অনুদাবন য আবেগ ভালোবাসা আম ইতিহাস কখনো পাব' with different Emotion:
#                                                     Text    Label
# 19828  আশির দশ আম জন্মে খেয়ে শুনে অনুদাবন য আবেগ ভাল...      joy
# 19829  আশির দশ আম জন্মে খেয়ে শুনে অনুদাবন য আবেগ ভাল...  sadness
# --------------------
# Similar text 'ইমরান এইচ সহযোগি থাবা মগাচিপ অনন্য আজাদ চুমা চুমির ইভেন্ট জনক মুক্ত চিন্তা বিজ্ঞান মনস্ক লেখা পড় দা তুল মুর্তি পুতুল উপাসনা দরক নে ভাংা ফ এসবএসব মুক্ত চিন্তা মানুষ মুক্ত চিন্ত আলোকিত মানুষে এসব অর্থহীন পুতুল মানুষ প্রভুত্ব করব মানা নি পার হিন্দু দেব মুর্তি ভাং পিছন সরাসরি যুক্ত নতুবা লেখা চিন্ত মাধ্যম মুক্ত চিন্তক প্রভাবিত কর' with different Emotion:
#                                                     Text    Label
# 26477  ইমরান এইচ সহযোগি থাবা মগাচিপ অনন্য আজাদ চুমা চ...  disgust
# 26592  ইমরান এইচ সহযোগি থাবা মগাচিপ অনন্য আজাদ চুমা চ...  disgust
# 26607  ইমরান এইচ সহযোগি থাবা মগাচিপ অনন্য আজাদ চুমা চ...  sadness
# 26609  ইমরান এইচ সহযোগি থাবা মগাচিপ অনন্য আজাদ চুমা চ...  sadness
# 26622  ইমরান এইচ সহযোগি থাবা মগাচিপ অনন্য আজাদ চুমা চ...  sadness
# --------------------
# Similar text 'ইমোশনাল গেলাম' with different Emotion:
#                Text     Label
# 1446  ইমোশনাল গেলাম     anger
# 7810  ইমোশনাল গেলাম  surprise
# --------------------
# Similar text 'ইসলাম রক্ষায় ভারতীয় ইসরাইল পন্য ইউরোপীয় পন্য আগ বর্জন করুন দেশীয় নাস্তিক ধোসর যমুনা গ্রপ সকল পন্য কেননা এইদেশ নাস্তিক সবচেয় শক্তিশালী মিড়িয়া টিভি টিভির মালিক নাস্তিক শিরমনি মোজাম্ম বাবু সিংহভাগ আয় যমুনা গ্রুপ পন্য বিক্রির মাধ্যম যমুনা গ্রপ পন্যর মধ্য উল্লেখযোগ্য ফ্রেস ব্রান্ড আ ময়দা সুজি আসুন যমুনা গ্রুপ সকল পন্য বর্জন কর ইসলাম নিজ মন আগ ফ্রেশ' with different Emotion:
#                                                     Text     Label
# 29251  ইসলাম রক্ষায় ভারতীয় ইসরাইল পন্য ইউরোপীয় পন্...     anger
# 29270  ইসলাম রক্ষায় ভারতীয় ইসরাইল পন্য ইউরোপীয় পন্...  surprise
# 29341  ইসলাম রক্ষায় ভারতীয় ইসরাইল পন্য ইউরোপীয় পন্...   sadness
# 29407  ইসলাম রক্ষায় ভারতীয় ইসরাইল পন্য ইউরোপীয় পন্...   sadness
# --------------------
# Similar text 'এক কথায় অসাধারণ' with different Emotion:
#                    Text Label
# 202    এক কথায় অসাধারণ   joy
# 8314   এক কথায় অসাধারণ   joy
# 10478  এক কথায় অসাধারণ  love
# 17796  এক কথায় অসাধারণ   joy
# 17812  এক কথায় অসাধারণ  love
# --------------------
# Similar text 'এক কথায় অসাধারন' with different Emotion:
#                    Text Label
# 1339   এক কথায় অসাধারন   joy
# 10849  এক কথায় অসাধারন  love
# 14425  এক কথায় অসাধারন   joy
# 18146  এক কথায় অসাধারন   joy
# --------------------
# Similar text 'এক গান' with different Emotion:
#         Text    Label
# 1594  এক গান     love
# 3424  এক গান  sadness
# --------------------
# Similar text 'এক চা' with different Emotion:
#        Text Label
# 4101  এক চা  love
# 8910  এক চা   joy
# --------------------
# Similar text 'এক জিন বুঝি বাংলাদেশ সরকারি বেসরকারি চ্যানেল অভাব নে এইসব সংবাদ গ্রেফতার আগ প্রচারণা ক ক আদালত বলবো পাপিয় বিরুদ্ধ চার্জশিট তৈরি ক কর জিবনে কারাগ মুক্তি পায় মড হাসা থাকুক' with different Emotion:
#                                                     Text    Label
# 6625   এক জিন বুঝি বাংলাদেশ সরকারি বেসরকারি চ্যানেল অ...  sadness
# 20472  এক জিন বুঝি বাংলাদেশ সরকারি বেসরকারি চ্যানেল অ...    anger
# --------------------
# Similar text 'এক সুখ সংস ধ্বংস কর শয়তান অস্ত্র আবিস্ক কর ত মধ্য মারাত্নক অস্ত্র স্ত্রীর ঘ্যানর ঘ্যানর' with different Emotion:
#                                                     Text    Label
# 21230  এক সুখ সংস ধ্বংস কর শয়তান অস্ত্র আবিস্ক কর ত ...  disgust
# 21231  এক সুখ সংস ধ্বংস কর শয়তান অস্ত্র আবিস্ক কর ত ...  sadness
# --------------------
# Similar text 'একমত' with different Emotion:
#        Text    Label
# 25371  একমত      joy
# 25520  একমত      joy
# 26313  একমত      joy
# 26377  একমত      joy
# 28052  একমত      joy
# 28220  একমত      joy
# 28235  একমত      joy
# 29998  একমত  sadness
# 30159  একমত      joy
# 31295  একমত      joy
# --------------------
# Similar text 'একমাত্র সরকারি আঙ্গুল চাপ দি রাজি আ শিক্ষিত ব্যক্তি আঙ্গুল চাপ নাআমি স্বাক্ষর কর জানি বায়োমেট্রিক পদ্ধতি দিয় দেশ মানুষ বিপ দি এগিয় নিয়' with different Emotion:
#                                                     Text     Label
# 29820  একমাত্র সরকারি আঙ্গুল চাপ দি রাজি আ শিক্ষিত ব্...  surprise
# 29865  একমাত্র সরকারি আঙ্গুল চাপ দি রাজি আ শিক্ষিত ব্...      fear
# --------------------
# Similar text 'একাজ কর তাদা মা কা একদিন রক্ত পান করব' with different Emotion:
#                                         Text    Label
# 26910  একাজ কর তাদা মা কা একদিন রক্ত পান করব    anger
# 27174  একাজ কর তাদা মা কা একদিন রক্ত পান করব  sadness
# --------------------
# Similar text 'কক্সবাজার কুতুবদিয়া উপজেলায় স্কুলছাত্র অচেতন কর ধর্ষণ অভিযোগ উঠ ঘটনায় আওয়ামী লীগ নেতা শেখ শহিদুল ইসলাম দোকান কর্মচারী মোহাম্মদ নওশাদ আটক কর পুলিশ' with different Emotion:
#                                                     Text    Label
# 21619  কক্সবাজার কুতুবদিয়া উপজেলায় স্কুলছাত্র অচেতন...    anger
# 21620  কক্সবাজার কুতুবদিয়া উপজেলায় স্কুলছাত্র অচেতন...  disgust
# --------------------
# Similar text 'কঠোর ব্যবস্থা শাস্তি দি হব অপকর্ম বাড়ব' with different Emotion:
#                                           Text    Label
# 30443  কঠোর ব্যবস্থা শাস্তি দি হব অপকর্ম বাড়ব    anger
# 30594  কঠোর ব্যবস্থা শাস্তি দি হব অপকর্ম বাড়ব  sadness
# --------------------
# Similar text 'কর' with different Emotion:
#       Text     Label
# 298     কর  surprise
# 721     কর  surprise
# 3874    কর       joy
# 6034    কর       joy
# 6237    কর       joy
# 7770    কর       joy
# 8310    কর  surprise
# 9977    কর  surprise
# 11954   কর       joy
# 12973   কর  surprise
# 14623   কর     anger
# 18623   কর       joy
# 26653   কর       joy
# 26683   কর  surprise
# 27238   কর   sadness
# 27623   কর       joy
# 27840   কর       joy
# 27845   কর       joy
# 27848   কর       joy
# 27945   কর       joy
# --------------------
# Similar text 'কর পারব কারন কথায় থানা পুলিশ উঠ বস এমপি মন্ত্রি হাত ময়লা খমতায় সাধারন জনগণ জায়গা জমি টাক্কা পয়সা হাতিয় নিয় কয়েশো কু টাক মালিক লোক পথ ফকির কর দিয় দেখি বিচ কর টাকা পয়সা নিয় ছেড়' with different Emotion:
#                                                     Text    Label
# 21569  কর পারব কারন কথায় থানা পুলিশ উঠ বস এমপি মন্ত্...    anger
# 21570  কর পারব কারন কথায় থানা পুলিশ উঠ বস এমপি মন্ত্...     fear
# 21571  কর পারব কারন কথায় থানা পুলিশ উঠ বস এমপি মন্ত্...  sadness
# --------------------
# Similar text 'কা এক অনুরুদ ক্রিকেট নির্বাচন রাজনিতি বাদ দিয় শুদু তনু হত্য বিচ দাবি এগিয় নিয় বির্তকিত সমালোচন কারন তনুর বিচার আন্দোলন নিচ পড় দামা চাপা যাব' with different Emotion:
#                                                     Text    Label
# 29336  কা এক অনুরুদ ক্রিকেট নির্বাচন রাজনিতি বাদ দিয়...     fear
# 29393  কা এক অনুরুদ ক্রিকেট নির্বাচন রাজনিতি বাদ দিয়...  sadness
# --------------------
# Similar text 'কাবিলা ভা' with different Emotion:
#            Text Label
# 3652  কাবিলা ভা  love
# 9608  কাবিলা ভা   joy
# --------------------
# Similar text 'কুকুর বাচ্চা' with different Emotion:
#                Text    Label
# 18100  কুকুর বাচ্চা  sadness
# 27890  কুকুর বাচ্চা    anger
# --------------------
# Similar text 'কোর্ট কল করল রাষ্ট্রপতি ব্যতীত প্রধানমন্ত্রী কর য ব্যাক্তি কোর্ট হাজির হ বাধ্য' with different Emotion:
#                                                     Text    Label
# 30345  কোর্ট কল করল রাষ্ট্রপতি ব্যতীত প্রধানমন্ত্রী ক...     fear
# 30384  কোর্ট কল করল রাষ্ট্রপতি ব্যতীত প্রধানমন্ত্রী ক...  disgust
# --------------------
# Similar text 'ক্যাম্পাস সবচেয় সুন্দর ব্যাপার ফুট উঠ রাত বাস মোহ একদম জীবন্ত লাগত ওয়াল গ্রেট জব জুনিয়রস' with different Emotion:
#                                                     Text     Label
# 22004  ক্যাম্পাস সবচেয় সুন্দর ব্যাপার ফুট উঠ রাত বাস...  surprise
# 22005  ক্যাম্পাস সবচেয় সুন্দর ব্যাপার ফুট উঠ রাত বাস...       joy
# --------------------
# Similar text 'খা সামন চইলা আস' with different Emotion:
#                   Text    Label
# 936    খা সামন চইলা আস      joy
# 10061  খা সামন চইলা আস  sadness
# --------------------
# Similar text 'গান অসাধারণ' with different Emotion:
#               Text Label
# 12495  গান অসাধারণ  love
# 19075  গান অসাধারণ   joy
# --------------------
# Similar text 'গান আম ভালো লাগ' with different Emotion:
#                   Text  Label
# 13113  গান আম ভালো লাগ    joy
# 19112  গান আম ভালো লাগ  anger
# --------------------
# Similar text 'গান শুন মুগ্ধ' with different Emotion:
#                 Text Label
# 2336   গান শুন মুগ্ধ   joy
# 15766  গান শুন মুগ্ধ  love
# --------------------
# Similar text 'গান সুন্দর' with different Emotion:
#              Text Label
# 2521   গান সুন্দর   joy
# 2939   গান সুন্দর   joy
# 7107   গান সুন্দর   joy
# 7215   গান সুন্দর   joy
# 9027   গান সুন্দর   joy
# 11946  গান সুন্দর  love
# 12864  গান সুন্দর   joy
# 12876  গান সুন্দর   joy
# 13868  গান সুন্দর   joy
# 15298  গান সুন্দর   joy
# 18462  গান সুন্দর   joy
# 18541  গান সুন্দর   joy
# 19096  গান সুন্দর   joy
# --------------------
# Similar text 'চমক ভা' with different Emotion:
#          Text     Label
# 3682   চমক ভা      love
# 3996   চমক ভা      love
# 14359  চমক ভা  surprise
# --------------------
# Similar text 'চমক হাসান ভা' with different Emotion:
#               Text Label
# 1761  চমক হাসান ভা   joy
# 4591  চমক হাসান ভা  love
# --------------------
# Similar text 'চোখ পানি চল আসলো' with different Emotion:
#                    Text    Label
# 13423  চোখ পানি চল আসলো    anger
# 16693  চোখ পানি চল আসলো    anger
# 29591  চোখ পানি চল আসলো  sadness
# --------------------
# Similar text 'চোখ পানি ধর' with different Emotion:
#               Text    Label
# 6327   চোখ পানি ধর    anger
# 29752  চোখ পানি ধর  sadness
# --------------------
# Similar text 'চোখ পানি ধর রাখ পারলাম' with different Emotion:
#                          Text    Label
# 7195   চোখ পানি ধর রাখ পারলাম    anger
# 12284  চোখ পানি ধর রাখ পারলাম    anger
# 30102  চোখ পানি ধর রাখ পারলাম  sadness
# --------------------
# Similar text 'চোর ম বড় গলা' with different Emotion:
#                 Text    Label
# 7490   চোর ম বড় গলা  sadness
# 30301  চোর ম বড় গলা    anger
# --------------------
# Similar text 'ছাগল' with different Emotion:
#        Text    Label
# 12967  ছাগল  sadness
# 26275  ছাগল    anger
# 27964  ছাগল  disgust
# 28920  ছাগল  disgust
# --------------------
# Similar text 'ছালা গালা ছালা পাবেবৈশাখ আনন্দ গালা যাব নাএ মেলা আস পরপুরুষ সাথ মজা নি' with different Emotion:
#                                                     Text    Label
# 28309  ছালা গালা ছালা পাবেবৈশাখ আনন্দ গালা যাব নাএ মে...  disgust
# 28345  ছালা গালা ছালা পাবেবৈশাখ আনন্দ গালা যাব নাএ মে...  sadness
# --------------------
# Similar text 'ছিলো' with different Emotion:
#        Text     Label
# 1820   ছিলো       joy
# 5277   ছিলো  surprise
# 14835  ছিলো      love
# 16974  ছিলো      love
# --------------------
# Similar text 'ছেলে সুন্দর' with different Emotion:
#               Text Label
# 3859   ছেলে সুন্দর  love
# 15514  ছেলে সুন্দর   joy
# --------------------
# Similar text 'জনাক হ সন্ধ্যা বেলায় আলোর মাঝ তাঁ দাখা পাব তোম দি হাত বাড়াল' with different Emotion:
#                                                     Text Label
# 7018   জনাক হ সন্ধ্যা বেলায় আলোর মাঝ তাঁ দাখা পাব তো...  love
# 12713  জনাক হ সন্ধ্যা বেলায় আলোর মাঝ তাঁ দাখা পাব তো...   joy
# --------------------
# Similar text 'টাকা থাকল ক' with different Emotion:
#              Text     Label
# 3262  টাকা থাকল ক       joy
# 6846  টাকা থাকল ক  surprise
# --------------------
# Similar text 'টানা এগারোব বাংলাদেশ সর্বোচ্চ রফতানিকারক স্বর্ণ ট্রফি অর্জন কর জাব অ্যান্ড জুবায় ফেব্রিক্স রোবব প্রতিষ্ঠান উপ ব্যবস্থাপনা পরিচালক মোহাম্মদ আবদুল্লাহ জাবের হা প্রধানমন্ত্রী শেখ হাসিনা পুরস্ক তুল দ' with different Emotion:
#                                                     Text     Label
# 22481  টানা এগারোব বাংলাদেশ সর্বোচ্চ রফতানিকারক স্বর্...       joy
# 22482  টানা এগারোব বাংলাদেশ সর্বোচ্চ রফতানিকারক স্বর্...  surprise
# --------------------
# Similar text 'টিভি গলাবাজি তথ্য বিকৃতির বিরুদ্ধ মাওলানা সাখাওয়াত হোস টিভি গলাবাজি তথ্য বিকৃতির বিরুদ্ধ মাওলানা সাখাওয়াত হোস একা ভাল জবাব দিয় প্রসঙ্গ রাষ্ট্রধর্ম ইসলাম নিয় একাত্তর জার্নাল গলাবাজি তথ্য বিকৃতি গতকাল একাত্তর জার্নাল মুফতী সাখাওয়াত হুসাইন রাষ্ট্রধর্ম ইসলাম নিয় প্রশ্ন ক শোন বারব থামিয় ভিন্ন প্রসঙ্গ ভুল তথ্য ছুঁড় বিভ্রান্ত কর চেষ্ ক অনুষ্ঠান য তিন মৌলিক প্রশ্ন ক পৃথিবীর কয় মুসলিম দাশা সংবিধান ইসলাম আ দাশা রাষ্ট্রধর্ম ইসলাম থাকল দাশা ইসলাম থাকব এরশাদ এক মতলব নিয় কর পরবর্তী বিএনপি ভয় বাদ নি ভিডি লিংক প্রশ্ন মুফতী সাহেব মধ্যপ্রাচ্য মুসলিম দেশসহ বিশ্ব মুসলিম দাশা সংবিধান রাষ্ট্রধর্ম ইসলাম থাক কথা উপস্থাপিকা জোর দিয় বল চেষ্ কর য ইন্দোনেশিয়া মালয়েশিয়া নে আরো ব ইরাক ইরানে নে মুফতী সাহেব মরক্কো আলজেরিয় কথা সেগুলো উপস্থাপিকা অস্বীক কর আম দেখি মালয়েশিয় রাষ্ট্রধর্ম ইসলাম ফেডেরাল কন্সটিটিউশন ভাগ অাুা দেখুন মালয়েশিয় সংবিধান ইরাক রাষ্ট্রধর্ম ইসলাম সংবিধান আ ইরাক সংবিধান ইরান রাষ্ট্রধর্ম ইসলাম শীয়া মতবাদ সংবিধান আ ইরান মূল সংবিধান আনঅফিশিয়াল অনুবাদ মরক্কোর রাষ্ট্রধর্ম ইসলাম সংবিধান আ মরক্কোর সংবিধান আলজেরিয় রাষ্ট্রধর্ম ইসলাম সংবিধান আ আলজেরিয় মূল সংবিধান অনুবাদ ইন্দোনেশিয় রাষ্ট্রধর্ম ইসলাম সংবিধান এক একমাত্র গড বিশ্বাস ইসলাম ধর্ম নে ইন্দোনেশিয় সংবিধান আরো যেসব দাশা রাষ্ট্রধর্ম ইসলাম দেখুন সুন্দর গলাবাজি কর বারব মালয়েশিয়া ইন্দোনেশিয় কথা হ দ্বিতীয় প্রশ্ন জান চাওয়া রাষ্ট্রধর্ম ইসলাম থাকল দাশা ইসলাম থাকব আমা প্রশ্ন রাষ্ট্রধর্ম ইসলাম সমান তাহল থাক সমস্যা ক তৃতীয় প্রশ্ন ব রাজনীতি মতলবের মতলব কব কথা বল বাকী মতলব জনগণ উপকারী কিনা প্রশ্ন আমা পাল্ প্রশ্ন সংবিধান ক রাষ্ট্রধর্ম ইসলাম স্থান পায় নি ক সেকুলারিজম জায়গা প কা মতলব দেশ জনসংখ্য পার্সেন্ট সেকুল আম রোজা মুক্তিযুদ্ধ কর গল্প জেনে নামায দোয়া কর যুদ্ধ ব হওয় দৃষ্টান্ত তাহল ত্যাগ অমর্যাদা ক মিনিট কথায় গলাবাজি মিথ্য আশ্রয় নিল কীভাব হব ভা সত্য দিয় মোকাবিলা করুন বুদ্ধিমান সাহসী থাক মাওলানা সাহেব লেখা' with different Emotion:
#                                                     Text    Label
# 29264  টিভি গলাবাজি তথ্য বিকৃতির বিরুদ্ধ মাওলানা সাখা...    anger
# 29293  টিভি গলাবাজি তথ্য বিকৃতির বিরুদ্ধ মাওলানা সাখা...  sadness
# --------------------
# Similar text 'ঢাকা দক্ষিণ করপোরেশন বিএনপির প্রার্থী ইশরাক হোসেন নির্বাচনী প্রচার সময় ক্ষমতাসীন আওয়ামী লীগ বিএনপির কর্মী সমর্থক মধ্য সংঘর্ষ ঘটনা ঘট সময় আওয়ামী লীগ বিএনপির সমর্থক মধ্য সংঘর্ষ পাল্টাপাল্ ধাওয় ঘটনা ঘট' with different Emotion:
#                                                     Text    Label
# 22543  ঢাকা দক্ষিণ করপোরেশন বিএনপির প্রার্থী ইশরাক হো...    anger
# 22544  ঢাকা দক্ষিণ করপোরেশন বিএনপির প্রার্থী ইশরাক হো...  disgust
# --------------------
# Similar text 'তনু একমাত্র তনু তনু আ শ মার্চ তম মহান স্বাধীনতা দিবস প্রধানমন্ত্রী শেখ হাসিন ক্ষোভ উত্তাল কুমিল্লা অবিলম্ব কুমিল্লা বিভাগ গঠন করুন কুমিল্লা ভিক্টোরিয়া সরকারি কলেজ ইতিহাস বিভাগ স্নাতক সম্মান দ্বিতীয় বর্ষ ছাত্রী নাট্যকর্মী সোহাগী জাহান তনু ধর্ষণ শাষা হত্যা ক কালভার্ট পাশ জঙ্গল মাথা থেত্লানো সোহাগীর অর্ধনগ্ন মৃতদেহ উদ্ধ ক ঘটনায় জড়িত অবিলম্ব গ্রেফত বিচ দাবি ক্ষোভ উত্তাল উঠ কুমিল্লা নগরী এদি তনুর বাড়ি চল ত বাবামা স্বজন আহাজারি কুমিল্লা ভিক্টোরিয়া কলেজ সরকারি মহিলা কলেজসহ নগরীর শিক্ষা প্রতিষ্ঠান দল নাবা হাজ হাজ শিক্ষার্থীসহ সামাজিক সাংস্কৃতিক সংগঠন নেতাকর্মী মাঠ নেম শিক্ষার্থীসহ প্রতিবাদী জনতা নগরী দফায় দফায় বিক্ষোভ মিছিল শাষা দুপুর কান্দিরপাড় পূবালী চত্ত্বর মানববন্ধন সমাবেশ কর রাজধানী ঢাকাসহ দেশ স্থান নিয় গত চ বিক্ষোভ প্রতিবাদ সমাবেশ ক হ ফেসবুকে বই প্রতিবা ঝড় জেলা গঠন প্রস্তাবমত বাংলাদেশ বিভাগ বিভক্ত রাষ্ট্রঅবকাঠামো শিথীলসন্ত্রাসমুখী সন্ত্রাসবাদীঅনৈতিক চেতনা ক্রমবর্ধমান খালেদা জিয়া অর্ধশিক্ষিত কমবুঝ প্রধানমন্ত্রী বরিশাল সিলেট বিভাগ গঠন কর বাকী তিন বিভাগ গঠন কর ব ব সত্তে শিক্ষিত বুঝ প্রধানমন্ত্রী শেখ হাসিনা ইউনিয়ন ওয়ার্ড বিভক্তির সাথ সাথ বাংলাদেশ বিভাগ বিভক্ত কর ব ব বলায় পাঁচ বছর ময়মনসিংহ বিভাগ কর বিগত সাতবছর প্রধানমন্ত্রী শেখ হাসিন সরকারামল প্রবৃদ্ধির গড় হ বছর প্রবৃদ্ধির হ হব বছর প্রধানমন্ত্রী শেখ হাসিনা ব ব শুনা প্রবৃদ্ধির গড় হ জাতির ইতিহাস এইসাথ কুমিল্লা বিভাগটি প্রবৃদ্ধির গড় হ ক্রমশ হ প্রধানমন্ত্রী শেখ হাসিনা ব ব কথা শুনা পারত কুমিল্লা বিভাগ বাকী আ বাংলাদেশ বিভাগ বিভক্তির এক বিভাগ প্রভাবশীল আন্দোলন হব কুমিল্লা বিভাগ গঠন বার্ষিক ব্যয় বাড়ব চারকে টাকা বাংলাদেশ বিভাগ বিভক্ত ক রাষ্ট্রঅবকাঠামো সুষমগণতন্ত্রমুখী হবেসকলক্ষেত্র উদ নৈতিক সৃজনশীল চেতনা বিকাশ ধা দাবা প্রবৃদ্ধি গড়হ বৃদ্ধিসহ জাতির নিরাপত্তা উন্নয়ণ ধা বাড়ব জরুরী ভিত্তি বাকী কুমিল্লা বিভাগ করুন' with different Emotion:
#                                                     Text     Label
# 29282  তনু একমাত্র তনু তনু আ শ মার্চ তম মহান স্বাধীনত...   sadness
# 29306  তনু একমাত্র তনু তনু আ শ মার্চ তম মহান স্বাধীনত...  surprise
# --------------------
# Similar text 'তনু হত্য বিচ চা সাংবাদিক ক নীর ক ভয়' with different Emotion:
#                                        Text    Label
# 29489  তনু হত্য বিচ চা সাংবাদিক ক নীর ক ভয়     fear
# 29562  তনু হত্য বিচ চা সাংবাদিক ক নীর ক ভয়  sadness
# --------------------
# Similar text 'তাবিব ভা' with different Emotion:
#            Text Label
# 14366  তাবিব ভা   joy
# 14953  তাবিব ভা  love
# --------------------
# Similar text 'তাহল কা কুমিল্লা ভিক্টোরিয়া কলেজ ছাত্রী তনু ধর্ষণ গলা কাটা হত্যা করলো সর্ষ ক্ষেতে ভূত কুমিল্লা সেনানিবাস এলাকায় চাঞ্চল্যকর হত্যাকান্ড তনু থা সেনানিবাস এরিয়ায় এমনকি ঘটন স এলাক বাইরে যায়নি স্থান তনু ধর্ষণ ক হয়েছিলো ত আশেপাশ আছে৷ তাহল ঐসব ফুটেজ গ্যালো ক আচ্ছা বাদ দেনআমা দাশা আব থা মাগ ফুটেজ থাকেনা সেনাবাহিনীর ফুটেজ মে হ্যাক হইস কিছুক্ষণ পরপর এমপি এফআ ডিজেএফআ আরপি টহল জায়গায় ঘটনাস্থল দুইপাশ সেনা ক্যাম্প কোয়া আ তাইল ক্যামন সেনানিবাস এলাকায় ঢুক গালা আপন গুষ্ তথ্য দিয় ঢুক হবেতাহল ধর্ষক বাইর ঢু থা তব সেনাবাহিনীর কা নিশ্চ তথ্য আ সঠিক যৌক্তিক প্রমান দেখানো সেনানিবাস ঢুকা যায়না' with different Emotion:
#                                                     Text     Label
# 29322  তাহল কা কুমিল্লা ভিক্টোরিয়া কলেজ ছাত্রী তনু ধ...      fear
# 29378  তাহল কা কুমিল্লা ভিক্টোরিয়া কলেজ ছাত্রী তনু ধ...  surprise
# --------------------
# Similar text 'তু আম শালী তোর দুলাভা' with different Emotion:
#                        Text Label
# 3649  তু আম শালী তোর দুলাভা   joy
# 6841  তু আম শালী তোর দুলাভা  love
# --------------------
# Similar text 'তোম' with different Emotion:
#       Text  Label
# 4225   তোম   love
# 6373   তোম  anger
# 17845  তোম   love
# --------------------
# Similar text 'দেশ সকল ম্যাজিস্ট্রেট ভাই দৃষ্ আকর্ষণ কর আপনা একত্রিত য় পোর্ট ম্যাজিস্ট্রেট পাশ দাড়ান বেয়াদপ কঠিন বিচ কর দাশা অন্যায় বিচ করল আন্দলন নাম বিচারকারি অপমান ক ফ্যাশন গ' with different Emotion:
#                                                     Text    Label
# 30317  দেশ সকল ম্যাজিস্ট্রেট ভাই দৃষ্ আকর্ষণ কর আপনা ...    anger
# 30411  দেশ সকল ম্যাজিস্ট্রেট ভাই দৃষ্ আকর্ষণ কর আপনা ...      joy
# 30533  দেশ সকল ম্যাজিস্ট্রেট ভাই দৃষ্ আকর্ষণ কর আপনা ...    anger
# 30562  দেশ সকল ম্যাজিস্ট্রেট ভাই দৃষ্ আকর্ষণ কর আপনা ...  sadness
# --------------------
# Similar text 'দেশরত্ন শেখ হাসিনা' with different Emotion:
#                     Text Label
# 2837  দেশরত্ন শেখ হাসিনা   joy
# 8446  দেশরত্ন শেখ হাসিনা  love
# --------------------
# Similar text 'দেহ দিলা মন দিলা' with different Emotion:
#                    Text  Label
# 771    দেহ দিলা মন দিলা  anger
# 2327   দেহ দিলা মন দিলা    joy
# 6511   দেহ দিলা মন দিলা  anger
# 10447  দেহ দিলা মন দিলা    joy
# 13564  দেহ দিলা মন দিলা  anger
# 16562  দেহ দিলা মন দিলা  anger
# 17098  দেহ দিলা মন দিলা    joy
# --------------------
# Similar text 'ধন্যবাদ তৌহিদ ভা' with different Emotion:
#                    Text Label
# 4915   ধন্যবাদ তৌহিদ ভা  love
# 11547  ধন্যবাদ তৌহিদ ভা   joy
# 12159  ধন্যবাদ তৌহিদ ভা   joy
# --------------------
# Similar text 'নড়াইল রবিশস্য সরিষ সঙ্গ মৌমা পালন কর মধু চাষ জনপ্রিয় উঠ একদি সরিষ ফলন বাড় অন্যদি বাড়তি আয় উৎস হ খাঁ মধু ফল সরিষ উৎপাদন বৃদ্ধির পাশাপাশি মধু বিক্রি কৃষক লাভবান হচ্ছ' with different Emotion:
#                                                     Text     Label
# 23030  নড়াইল রবিশস্য সরিষ সঙ্গ মৌমা পালন কর মধু চাষ ...       joy
# 23031  নড়াইল রবিশস্য সরিষ সঙ্গ মৌমা পালন কর মধু চাষ ...  surprise
# --------------------
# Similar text 'নাটক' with different Emotion:
#        Text    Label
# 841    নাটক     love
# 17733  নাটক      joy
# 19085  নাটক  sadness
# 27666  নাটক  disgust
# 28809  নাটক      joy
# --------------------
# Similar text 'নাটক দাখা মজা পেলাম' with different Emotion:
#                      Text  Label
# 592   নাটক দাখা মজা পেলাম  anger
# 9962  নাটক দাখা মজা পেলাম    joy
# --------------------
# Similar text 'নিরাপত্তা প্রধান সকল চুরির হোতা ওনা যথাযথ আইনি প্রক্রিয়ায় এন বিচ ক আশাকরি অন্যায় কা নতি শিক কর' with different Emotion:
#                                                     Text    Label
# 30483  নিরাপত্তা প্রধান সকল চুরির হোতা ওনা যথাযথ আইনি...      joy
# 30552  নিরাপত্তা প্রধান সকল চুরির হোতা ওনা যথাযথ আইনি...  sadness
# 30561  নিরাপত্তা প্রধান সকল চুরির হোতা ওনা যথাযথ আইনি...     fear
# --------------------
# Similar text 'পাগল' with different Emotion:
#        Text    Label
# 27919  পাগল  disgust
# 28628  পাগল  sadness
# --------------------
# Similar text 'পাপিয়া ভাল সৎ নারী পুরুষ কান্ন আওয়াজ শুন স প্রভাব শালী যৌন চাহিদা মিটা গিয় বয়স বাচ্চা মেয়ে জীবন একেবার নস্ট কর দিয় ত সাথ জড়িত রয় আমা দেশ প্রভাব শালী আমলা সচিব সরকারী অফিস পুলিশ শিল্প পতি বাবসায়ি মজা লুট এক উঠতি বয়স মেয় কিশরি জীবন চিরতর শেষ কর দিয় জীবন পারব আগ মত ফিরিয় দি পুরো দুনিয়া বিক্রয় স আপনা ফিরিয় দি পারবেনা আম এহ জঘন অপরাধির জড়িত সকল সকল সামন রাস্তায় খোলা ফাঁসী চা' with different Emotion:
#                                                     Text    Label
# 23212  পাপিয়া ভাল সৎ নারী পুরুষ কান্ন আওয়াজ শুন স প...    anger
# 23213  পাপিয়া ভাল সৎ নারী পুরুষ কান্ন আওয়াজ শুন স প...  sadness
# --------------------
# Similar text 'পারভেজ ভা' with different Emotion:
#             Text Label
# 7424   পারভেজ ভা  love
# 13248  পারভেজ ভা  love
# 18580  পারভেজ ভা   joy
# --------------------
# Similar text 'পালাব স আকাশ জোনাক পোকা বল মর' with different Emotion:
#                                 Text Label
# 8747   পালাব স আকাশ জোনাক পোকা বল মর   joy
# 11649  পালাব স আকাশ জোনাক পোকা বল মর  love
# --------------------
# Similar text 'পৃথিবী আনন্দ দুখ সময় থাকব সমান সমান বিজ্ঞান ভাষায় আনন্ সংরক্ষণশীলতা একজন চরম আনন্দ পালা চরম দুখ পাতা হব' with different Emotion:
#                                                     Text    Label
# 23261  পৃথিবী আনন্দ দুখ সময় থাকব সমান সমান বিজ্ঞান ভ...      joy
# 23262  পৃথিবী আনন্দ দুখ সময় থাকব সমান সমান বিজ্ঞান ভ...  sadness
# --------------------
# Similar text 'পৃথিবী আপন মত মানুষ আ বলেপৃথিবী সুন্দরধর্ম মানুষ বড়সত্যি আপনা ধন্যবাদ দিয় ছোট কর' with different Emotion:
#                                                     Text Label
# 26599  পৃথিবী আপন মত মানুষ আ বলেপৃথিবী সুন্দরধর্ম মান...   joy
# 27453  পৃথিবী আপন মত মানুষ আ বলেপৃথিবী সুন্দরধর্ম মান...  fear
# --------------------
# Similar text 'প্রতিমা ভেঙ পুরোহিত মুয়াজ্জিন হত্যা কর ধর্ম নে মানব নাম বর্বর নরপিশাচ ধর্ম শত্রু' with different Emotion:
#                                                     Text    Label
# 26608  প্রতিমা ভেঙ পুরোহিত মুয়াজ্জিন হত্যা কর ধর্ম ন...  sadness
# 27300  প্রতিমা ভেঙ পুরোহিত মুয়াজ্জিন হত্যা কর ধর্ম ন...    anger
# --------------------
# Similar text 'প্রশ্ন শুন বুঝা বাংলাদেশ অধিকাংশ সাংবাদিক এক এক নিচু মান উৎকৃষ্ট দালাল' with different Emotion:
#                                                     Text    Label
# 23347  প্রশ্ন শুন বুঝা বাংলাদেশ অধিকাংশ সাংবাদিক এক এ...    anger
# 23348  প্রশ্ন শুন বুঝা বাংলাদেশ অধিকাংশ সাংবাদিক এক এ...  disgust
# --------------------
# Similar text 'ফাসি' with different Emotion:
#        Text    Label
# 10122  ফাসি  sadness
# 31484  ফাসি    anger
# --------------------
# Similar text 'বছর প্রতিবেদন সালমান শাহ আত্মহত্যা কর বছর সাংবাদিক সাগর রুনির প্রতিবেদন হব অপর হত্যা কর আত্মহত্যা কর' with different Emotion:
#                                                     Text    Label
# 19811  বছর প্রতিবেদন সালমান শাহ আত্মহত্যা কর বছর সাংব...     fear
# 19812  বছর প্রতিবেদন সালমান শাহ আত্মহত্যা কর বছর সাংব...  sadness
# --------------------
# Similar text 'বল' with different Emotion:
#       Text    Label
# 225     বল      joy
# 7837    বল    anger
# 7841    বল      joy
# 8189    বল    anger
# 11475   বল      joy
# 14101   বল    anger
# 18250   বল      joy
# 26978   বল      joy
# 27014   বল    anger
# 27811   বল      joy
# 28049   বল      joy
# 28239   বল  sadness
# 30162   বল      joy
# --------------------
# Similar text 'বস' with different Emotion:
#      Text Label
# 4092   বস  love
# 5886   বস   joy
# --------------------
# Similar text 'বাংলাদেশ তথ্যপ্রযুক্তি প্রযুক্তি বিনিয়োগকারী প্রতিষ্ঠান ইজেনারেশন লিমিটেড ভারত এইচসিসি গ্রুপ সহযোগী প্রতিষ্ঠান হাইব টেকনোক্রাট লিমিটেড সাথ সমঝোতা চুক্তি স্বাক্ষর প্রধানমন্ত্রী শেখ হাসিন ভার রাষ্ট্রীয় সফরকাল শুক্রব নয়াদিল্লীর আইটিসি মোর্য হাটা ভারত বাংলাদেশ বিজনেস ফোরাম আইবিবিএফ উদ্বোধন শাষা সমঝোতা চুক্তি স্বাক্ষরিত' with different Emotion:
#                                                     Text  Label
# 23573  বাংলাদেশ তথ্যপ্রযুক্তি প্রযুক্তি বিনিয়োগকারী ...  anger
# 23574  বাংলাদেশ তথ্যপ্রযুক্তি প্রযুক্তি বিনিয়োগকারী ...    joy
# --------------------
# Similar text 'বাংলাদেশ পুলিশ পরিচয় গোপন কর কা চাকরী কর দেখুন' with different Emotion:
#                                                   Text     Label
# 26264  বাংলাদেশ পুলিশ পরিচয় গোপন কর কা চাকরী কর দেখুন  surprise
# 27580  বাংলাদেশ পুলিশ পরিচয় গোপন কর কা চাকরী কর দেখুন   sadness
# --------------------
# Similar text 'বানান ভুল' with different Emotion:
#             Text    Label
# 30145  বানান ভুল  sadness
# 30215  বানান ভুল  disgust
# 30363  বানান ভুল  disgust
# --------------------
# Similar text 'বিচ' with different Emotion:
#       Text    Label
# 27733  বিচ  sadness
# 27851  বিচ    anger
# --------------------
# Similar text 'বিচ ক কা চাইব আইন মানুষ বড় অসয়া' with different Emotion:
#                                     Text     Label
# 29428  বিচ ক কা চাইব আইন মানুষ বড় অসয়া  surprise
# 29432  বিচ ক কা চাইব আইন মানুষ বড় অসয়া   sadness
# --------------------
# Similar text 'বিচ চা' with different Emotion:
#          Text    Label
# 27588  বিচ চা  sadness
# 27678  বিচ চা    anger
# 27802  বিচ চা  sadness
# 27831  বিচ চা    anger
# 27834  বিচ চা    anger
# 27846  বিচ চা    anger
# 27863  বিচ চা    anger
# 27864  বিচ চা    anger
# 27866  বিচ চা    anger
# 27889  বিচ চা    anger
# 27934  বিচ চা  sadness
# 28005  বিচ চা    anger
# 28229  বিচ চা  disgust
# --------------------
# Similar text 'বিমানবন্দর প্রধান নিরাপত্তা কর্মকর্ত বিরুদ্ধ আইনানুগ সর্বোচ্চ কঠিন শাস্তি দেওয় অনুরোধ ম্যাজিস্ট্রেট চোর ধর শাস্তি দেওয়ায় চোর ঐক্যবদ্ধ চোর কা কোনভাবে হারা যাতা পার' with different Emotion:
#                                                     Text    Label
# 30569  বিমানবন্দর প্রধান নিরাপত্তা কর্মকর্ত বিরুদ্ধ আ...  sadness
# 30575  বিমানবন্দর প্রধান নিরাপত্তা কর্মকর্ত বিরুদ্ধ আ...      joy
# --------------------
# Similar text 'বিয় কর' with different Emotion:
#           Text  Label
# 8136   বিয় কর    joy
# 16098  বিয় কর  anger
# --------------------
# Similar text 'বিশ্বব্যাপী ছড়িয় পড় করোনাভাইরাস চীন বাইর ফ্রান্স জাপান অস্ট্রেলিয়া মালয়েশিয়া নেপাল সিঙ্গাপুর দক্ষিণ কোরিয়া তাইওয়ান থাইল্যান্ড যুক্তরাষ্ট্র ভিয়েতনাম ভাইরাস সংক্রমিত রোগী শনাক্ত ক গ' with different Emotion:
#                                                     Text    Label
# 23766  বিশ্বব্যাপী ছড়িয় পড় করোনাভাইরাস চীন বাইর ফ্...  disgust
# 23767  বিশ্বব্যাপী ছড়িয় পড় করোনাভাইরাস চীন বাইর ফ্...     fear
# --------------------
# Similar text 'বুজলাম' with different Emotion:
#          Text     Label
# 5162   বুজলাম     anger
# 29062  বুজলাম  surprise
# --------------------
# Similar text 'ভা' with different Emotion:
#       Text  Label
# 455     ভা    joy
# 1058    ভা    joy
# 1912    ভা  anger
# 5076    ভা    joy
# 5867    ভা    joy
# 6893    ভা  anger
# 7289    ভা    joy
# 7973    ভা    joy
# 8573    ভা   love
# 11211   ভা    joy
# 12824   ভা    joy
# 13921   ভা    joy
# 14071   ভা   love
# 17347   ভা  anger
# 28223   ভা   fear
# --------------------
# Similar text 'ভা আজকে আপন ভিডি দেখলাম ভালো লাগ গ স্যলুট বস চালিয় সাবস্ক্রাইব করলাম' with different Emotion:
#                                                     Text     Label
# 23922  ভা আজকে আপন ভিডি দেখলাম ভালো লাগ গ স্যলুট বস চ...       joy
# 23923  ভা আজকে আপন ভিডি দেখলাম ভালো লাগ গ স্যলুট বস চ...  surprise
# --------------------
# Similar text 'ভা আপনা ধন্যবাদ' with different Emotion:
#                   Text Label
# 5716   ভা আপনা ধন্যবাদ  love
# 6766   ভা আপনা ধন্যবাদ  love
# 10677  ভা আপনা ধন্যবাদ   joy
# 26059  ভা আপনা ধন্যবাদ   joy
# 27938  ভা আপনা ধন্যবাদ   joy
# --------------------
# Similar text 'ভা ভালো লাগ' with different Emotion:
#               Text Label
# 5808   ভা ভালো লাগ   joy
# 9933   ভা ভালো লাগ   joy
# 14364  ভা ভালো লাগ  love
# --------------------
# Similar text 'ভারতীয় মালাউন বাংলাদেশি পতাকা অবমাননা কর নিয় প্রতিবেদন করুন' with different Emotion:
#                                                     Text    Label
# 17245  ভারতীয় মালাউন বাংলাদেশি পতাকা অবমাননা কর নিয়...  sadness
# 24023  ভারতীয় মালাউন বাংলাদেশি পতাকা অবমাননা কর নিয়...    anger
# --------------------
# Similar text 'ভাল' with different Emotion:
#       Text  Label
# 1275   ভাল    joy
# 9515   ভাল    joy
# 12437  ভাল  anger
# 27800  ভাল    joy
# 28703  ভাল    joy
# 30100  ভাল    joy
# 30647  ভাল    joy
# 31269  ভাল    joy
# --------------------
# Similar text 'ভাল কর' with different Emotion:
#          Text    Label
# 4482   ভাল কর      joy
# 18321  ভাল কর  sadness
# 26571  ভাল কর      joy
# 27633  ভাল কর      joy
# 27701  ভাল কর      joy
# 27987  ভাল কর      joy
# 27988  ভাল কর      joy
# --------------------
# Similar text 'ভাল লাগ' with different Emotion:
#           Text  Label
# 4132   ভাল লাগ    joy
# 5893   ভাল লাগ    joy
# 7394   ভাল লাগ    joy
# 11826  ভাল লাগ    joy
# 13370  ভাল লাগ    joy
# 13555  ভাল লাগ  anger
# 13679  ভাল লাগ    joy
# --------------------
# Similar text 'ভাল লাগলো' with different Emotion:
#             Text Label
# 2672   ভাল লাগলো   joy
# 3310   ভাল লাগলো   joy
# 5385   ভাল লাগলো   joy
# 9945   ভাল লাগলো   joy
# 10144  ভাল লাগলো  love
# 12111  ভাল লাগলো   joy
# 16456  ভাল লাগলো   joy
# 19210  ভাল লাগলো   joy
# 28689  ভাল লাগলো   joy
# 31397  ভাল লাগলো   joy
# --------------------
# Similar text 'ভালো' with different Emotion:
#        Text  Label
# 1232   ভালো    joy
# 1302   ভালো  anger
# 1425   ভালো   love
# 2274   ভালো    joy
# 2948   ভালো    joy
# 4106   ভালো    joy
# 4303   ভালো  anger
# 4587   ভালো    joy
# 5250   ভালো    joy
# 12523  ভালো    joy
# 12830  ভালো    joy
# 13628  ভালো    joy
# 14390  ভালো    joy
# 14995  ভালো    joy
# 16148  ভালো    joy
# 26561  ভালো    joy
# 27850  ভালো    joy
# 28722  ভালো    joy
# 29732  ভালো    joy
# --------------------
# Similar text 'ভালো থাকো' with different Emotion:
#             Text Label
# 15277  ভালো থাকো   joy
# 16460  ভালো থাকো  love
# --------------------
# Similar text 'ভালো ভা' with different Emotion:
#           Text Label
# 1100   ভালো ভা   joy
# 16463  ভালো ভা  love
# --------------------
# Similar text 'ভালো লাগ' with different Emotion:
#            Text  Label
# 3636   ভালো লাগ    joy
# 4097   ভালো লাগ    joy
# 4934   ভালো লাগ    joy
# 5673   ভালো লাগ    joy
# 6568   ভালো লাগ    joy
# 9362   ভালো লাগ  anger
# 10319  ভালো লাগ    joy
# 10382  ভালো লাগ    joy
# 12150  ভালো লাগ    joy
# 12925  ভালো লাগ  anger
# 13666  ভালো লাগ    joy
# 15224  ভালো লাগ    joy
# 16818  ভালো লাগ    joy
# 19136  ভালো লাগ    joy
# --------------------
# Similar text 'ভালো লাগলো' with different Emotion:
#              Text  Label
# 2105   ভালো লাগলো    joy
# 2918   ভালো লাগলো    joy
# 3055   ভালো লাগলো    joy
# 3240   ভালো লাগলো    joy
# 3502   ভালো লাগলো    joy
# 4012   ভালো লাগলো    joy
# 4349   ভালো লাগলো    joy
# 4510   ভালো লাগলো    joy
# 6015   ভালো লাগলো    joy
# 7885   ভালো লাগলো    joy
# 8120   ভালো লাগলো  anger
# 9108   ভালো লাগলো    joy
# 9567   ভালো লাগলো    joy
# 9863   ভালো লাগলো    joy
# 10033  ভালো লাগলো    joy
# 10987  ভালো লাগলো    joy
# 11691  ভালো লাগলো    joy
# 13427  ভালো লাগলো    joy
# 14434  ভালো লাগলো    joy
# 14655  ভালো লাগলো    joy
# 15390  ভালো লাগলো    joy
# 15433  ভালো লাগলো    joy
# 16259  ভালো লাগলো   love
# 16722  ভালো লাগলো    joy
# 16885  ভালো লাগলো    joy
# 17295  ভালো লাগলো    joy
# 17726  ভালো লাগলো    joy
# 17942  ভালো লাগলো    joy
# 18503  ভালো লাগলো    joy
# 29712  ভালো লাগলো    joy
# --------------------
# Similar text 'ভালো লাগলো আফ্রিদি ভা' with different Emotion:
#                        Text Label
# 2385  ভালো লাগলো আফ্রিদি ভা  love
# 3196  ভালো লাগলো আফ্রিদি ভা   joy
# 4795  ভালো লাগলো আফ্রিদি ভা   joy
# --------------------
# Similar text 'ভালো লেগ' with different Emotion:
#            Text Label
# 3796   ভালো লেগ   joy
# 6200   ভালো লেগ   joy
# 6401   ভালো লেগ   joy
# 13393  ভালো লেগ  love
# 15002  ভালো লেগ   joy
# --------------------
# Similar text 'ভালো হই' with different Emotion:
#           Text Label
# 5082   ভালো হই   joy
# 8719   ভালো হই   joy
# 11982  ভালো হই  love
# --------------------
# Similar text 'ভিনগ্রহ আবাল ইউটিউব চালায় সুন্দর এক ভিডি ডিসলাইক এইসব ডিসলাইকার থাপড়া মন' with different Emotion:
#                                                     Text    Label
# 21835  ভিনগ্রহ আবাল ইউটিউব চালায় সুন্দর এক ভিডি ডিসল...    anger
# 21836  ভিনগ্রহ আবাল ইউটিউব চালায় সুন্দর এক ভিডি ডিসল...  disgust
# --------------------
# Similar text 'ভূত মুখ রাম রাম' with different Emotion:
#                   Text    Label
# 26270  ভূত মুখ রাম রাম    anger
# 26351  ভূত মুখ রাম রাম  sadness
# 26447  ভূত মুখ রাম রাম  sadness
# --------------------
# Similar text 'মজা পাইলাম' with different Emotion:
#              Text    Label
# 6010   মজা পাইলাম    anger
# 6029   মজা পাইলাম  sadness
# 10535  মজা পাইলাম      joy
# 11092  মজা পাইলাম      joy
# 15354  মজা পাইলাম      joy
# 18930  মজা পাইলাম      joy
# --------------------
# Similar text 'মন ছুয় গ' with different Emotion:
#             Text Label
# 7436   মন ছুয় গ  love
# 18330  মন ছুয় গ   joy
# --------------------
# Similar text 'মা' with different Emotion:
#       Text    Label
# 9842    মা  sadness
# 28752   মা  sadness
# 28807   মা      joy
# --------------------
# Similar text 'মানুষ' with different Emotion:
#         Text     Label
# 93     মানুষ     anger
# 12734  মানুষ  surprise
# 13982  মানুষ   sadness
# 27873  মানুষ   sadness
# 27946  মানুষ   sadness
# 27947  মানুষ   disgust
# --------------------
# Similar text 'মানুষ জানোয়' with different Emotion:
#                Text    Label
# 8344   মানুষ জানোয়  sadness
# 14930  মানুষ জানোয়  sadness
# 26937  মানুষ জানোয়    anger
# --------------------
# Similar text 'মানুষ ধর্ম ব্যবহ চল এসব' with different Emotion:
#                           Text    Label
# 29423  মানুষ ধর্ম ব্যবহ চল এসব  sadness
# 29435  মানুষ ধর্ম ব্যবহ চল এসব  disgust
# --------------------
# Similar text 'মিনিট' with different Emotion:
#         Text     Label
# 2375   মিনিট     anger
# 11872  মিনিট  surprise
# --------------------
# Similar text 'মিষ্টি প্রতিদিন পোকা ধর' with different Emotion:
#                           Text    Label
# 5509   মিষ্টি প্রতিদিন পোকা ধর    anger
# 12969  মিষ্টি প্রতিদিন পোকা ধর  sadness
# --------------------
# Similar text 'মুসলিম হিন্দু' with different Emotion:
#                 Text     Label
# 27159  মুসলিম হিন্দু   disgust
# 27352  মুসলিম হিন্দু  surprise
# --------------------
# Similar text 'যেভাব কথা বলত মন জনগন বিপুল পরিমান ভোট পেয় ক্ষমতায় নির্লজ্জ কোথাক' with different Emotion:
#                                                     Text    Label
# 20909  যেভাব কথা বলত মন জনগন বিপুল পরিমান ভোট পেয় ক্...    anger
# 20910  যেভাব কথা বলত মন জনগন বিপুল পরিমান ভোট পেয় ক্...  disgust
# --------------------
# Similar text 'রকিবুল কম যাননি ভারতীয় বোলার বোলিং তোপ সামল অধিনায়ক সঙ্গ দিয় গ অসাধারণ কৃতিত্ব দল জয় বন্দর পৌঁ মাঠ ছেড় দুজন' with different Emotion:
#                                                     Text     Label
# 24499  রকিবুল কম যাননি ভারতীয় বোলার বোলিং তোপ সামল অ...       joy
# 24500  রকিবুল কম যাননি ভারতীয় বোলার বোলিং তোপ সামল অ...  surprise
# --------------------
# Similar text 'রশি দিয় ব্যান লাগানো অনুষ্ঠান প্রচন্ড মানহানীর বিষয় অনুষ্ঠান ব্যবস্থাপনায় ছি জবাবদিহীতায় আনা' with different Emotion:
#                                                     Text    Label
# 24514  রশি দিয় ব্যান লাগানো অনুষ্ঠান প্রচন্ড মানহানী...    anger
# 24515  রশি দিয় ব্যান লাগানো অনুষ্ঠান প্রচন্ড মানহানী...  disgust
# --------------------
# Similar text 'রাইট' with different Emotion:
#        Text  Label
# 25824  রাইট    joy
# 27662  রাইট    joy
# 27961  রাইট  anger
# 28240  রাইট    joy
# 30115  রাইট    joy
# --------------------
# Similar text 'রান ক সদস্য পা' with different Emotion:
#                  Text     Label
# 10199  রান ক সদস্য পা  surprise
# 13526  রান ক সদস্য পা       joy
# --------------------
# Similar text 'ল ঠেলা' with different Emotion:
#          Text    Label
# 4345   ল ঠেলা      joy
# 18554  ল ঠেলা  sadness
# --------------------
# Similar text 'লেবুর শরব আয়েশ কর চুমুক দি দি পাশ দেয়াল দৃষ্ ফেরাতে চোখ আট হা আঁকা ছবির দি য ছবি শোভা পা বৃষ্টিভেজা একফা লেবুর ছ গ স্বাদ দ্বিগুণ আহা স্নিগ্ধতা সতেজভাব য মুহূর্তে ছেয় ফেল শরীর মন গ ছবির কথা অন্দরসজ্জায় লেবুর রকমারি সাজ আপন প্রিয় অঙ্গন দাবা সতেজ হাসি' with different Emotion:
#                                                     Text     Label
# 24659  লেবুর শরব আয়েশ কর চুমুক দি দি পাশ দেয়াল দৃষ্...       joy
# 24660  লেবুর শরব আয়েশ কর চুমুক দি দি পাশ দেয়াল দৃষ্...  surprise
# --------------------
# Similar text 'লোক য রাজাক শিরমণি গু আজম পরিব গায় জোর ভি আ সুবিধা দিয়' with different Emotion:
#                                                     Text    Label
# 30340  লোক য রাজাক শিরমণি গু আজম পরিব গায় জোর ভি আ স...    anger
# 30347  লোক য রাজাক শিরমণি গু আজম পরিব গায় জোর ভি আ স...    anger
# 30601  লোক য রাজাক শিরমণি গু আজম পরিব গায় জোর ভি আ স...  sadness
# --------------------
# Similar text 'শফিক রেহমান অপরাধী অপরাধী করছ কা প্রশ্ন ক বড় অপরাধী নিশ্চয় বিরাট বড় ক্রিমিনাল তাইনা মহা আয়োজন কর গ্রেফত ক আচ্ছা দাশা একেরপর এক য মানুষ খুন হ খুনি ধ হ ক য ব্যাংক এতো টাকা লুট ক কাউ ধ তনুসহ এক এক খুনধর্ষণ চল খুনিধর্ষক ধর ক আচ্ছা শফিক রেহমান ত বড় ক্রিমিনাল তাইনা আজব ব্যাপ ফাজলামির এক সীমা আ' with different Emotion:
#                                                     Text    Label
# 25376  শফিক রেহমান অপরাধী অপরাধী করছ কা প্রশ্ন ক বড় ...    anger
# 26145  শফিক রেহমান অপরাধী অপরাধী করছ কা প্রশ্ন ক বড় ...  disgust
# --------------------
# Similar text 'শালা বাইনচোদ বাংলাদেশ খেলতে পার আব নাটক চোদা কা' with different Emotion:
#                                                   Text    Label
# 24698  শালা বাইনচোদ বাংলাদেশ খেলতে পার আব নাটক চোদা কা    anger
# 24699  শালা বাইনচোদ বাংলাদেশ খেলতে পার আব নাটক চোদা কা  disgust
# --------------------
# Similar text 'শালা স্বরাষ্ট্রপ্রতিমন্ত্রী তোর মত ছাগল য কিভাব মন্ত্রী বুঝিনা বাংলাদেশ ভালো ভালো লোক থাক আসল নির্বাচিত অবৈধভাব ক্ষমতায় আস' with different Emotion:
#                                                     Text    Label
# 24702  শালা স্বরাষ্ট্রপ্রতিমন্ত্রী তোর মত ছাগল য কিভা...    anger
# 24703  শালা স্বরাষ্ট্রপ্রতিমন্ত্রী তোর মত ছাগল য কিভা...  disgust
# --------------------
# Similar text 'শালির ঘর শা' with different Emotion:
#              Text    Label
# 359   শালির ঘর শা  sadness
# 706   শালির ঘর শা  sadness
# 3430  শালির ঘর শা      joy
# 8094  শালির ঘর শা      joy
# --------------------
# Similar text 'শালী আম খা খা' with different Emotion:
#                Text    Label
# 3681  শালী আম খা খা  sadness
# 5706  শালী আম খা খা      joy
# --------------------
# Similar text 'শালীর ঘর শালী' with different Emotion:
#                 Text    Label
# 401    শালীর ঘর শালী  sadness
# 4990   শালীর ঘর শালী      joy
# 11809  শালীর ঘর শালী  sadness
# 18512  শালীর ঘর শালী  sadness
# --------------------
# Similar text 'শীত শাষা সবজির দাম কম কমেনি শীতকাল সবজির দাম কেমন ত বেঞ্চমার্ক নির্দেশক মাঝারি আকার এক ফুলকপি এখনো টাক কম ছোট এক লাউয় দাম টাকা' with different Emotion:
#                                                     Text     Label
# 24725  শীত শাষা সবজির দাম কম কমেনি শীতকাল সবজির দাম ক...   sadness
# 24726  শীত শাষা সবজির দাম কম কমেনি শীতকাল সবজির দাম ক...  surprise
# --------------------
# Similar text 'সঠিক কথা বল' with different Emotion:
#               Text Label
# 6801   সঠিক কথা বল   joy
# 10967  সঠিক কথা বল   joy
# 13328  সঠিক কথা বল  love
# --------------------
# Similar text 'সত্যি' with different Emotion:
#         Text     Label
# 1035   সত্যি  surprise
# 28227  সত্যি       joy
# --------------------
# Similar text 'সত্যি অসাধারণ' with different Emotion:
#                 Text     Label
# 128    সত্যি অসাধারণ       joy
# 6086   সত্যি অসাধারণ      love
# 29702  সত্যি অসাধারণ  surprise
# 29716  সত্যি অসাধারণ  surprise
# --------------------
# Similar text 'সবসময় নিজেক সুখী ভা কখনো কারো কা প্রত্যাশা কারো কা প্রত্যাশা সবসময় দুখ দাঁড়ায়' with different Emotion:
#                                                     Text    Label
# 20665  সবসময় নিজেক সুখী ভা কখনো কারো কা প্রত্যাশা কা...      joy
# 20666  সবসময় নিজেক সুখী ভা কখনো কারো কা প্রত্যাশা কা...  sadness
# --------------------
# Similar text 'সময় টিভি ধন্যবাদ' with different Emotion:
#                     Text Label
# 10099  সময় টিভি ধন্যবাদ  love
# 17829  সময় টিভি ধন্যবাদ   joy
# --------------------
# Similar text 'সরাসরি ঘোষনা দ আপন ধর্ম ইসলাম শাহবাগ নাস্তিক ভুল তাহল আম আপন পাশ থাকি থাকি আল্লাহ আপন পাশ আছ' with different Emotion:
#                                                     Text Label
# 25605  সরাসরি ঘোষনা দ আপন ধর্ম ইসলাম শাহবাগ নাস্তিক ভ...   joy
# 28068  সরাসরি ঘোষনা দ আপন ধর্ম ইসলাম শাহবাগ নাস্তিক ভ...  fear
# --------------------
# Similar text 'সহমত পোষণ করছিভাল ভাল কালো কালো বিবেক সম্পন্ন মানুষ কর্তব্য বল মন করিযা সমালোচনা কর কতটুকু বিবেক প্রসুত ভাবা দেখ' with different Emotion:
#                                                     Text    Label
# 25599  সহমত পোষণ করছিভাল ভাল কালো কালো বিবেক সম্পন্ন ...      joy
# 25616  সহমত পোষণ করছিভাল ভাল কালো কালো বিবেক সম্পন্ন ...  sadness
# 25781  সহমত পোষণ করছিভাল ভাল কালো কালো বিবেক সম্পন্ন ...     fear
# --------------------
# Similar text 'সাল মার্চ সংঘা জর্জর আ ইয়েম সময় হুতি বিদ্রোহী দেশ পশ্চিমাঞ্চল নিয়ন্ত্রণ নিয় নেয় প্রেসিডেন্ট হাদি বাদা পালিয় যাতা বাধ্য কর বিশ্লেষক ম ইা়া গৃহযুদ্ধ আড়াল সৌদি আরবসহ সুন্নি দেশ সঙ্গ ছায়াযুদ্ধ চল শিয়া মতাবলম্বী ইরান' with different Emotion:
#                                                     Text    Label
# 19792  সাল মার্চ সংঘা জর্জর আ ইয়েম সময় হুতি বিদ্রোহ...     fear
# 19793  সাল মার্চ সংঘা জর্জর আ ইয়েম সময় হুতি বিদ্রোহ...  sadness
# --------------------
# Similar text 'সাহিত্য সাথ টাকা পয়স নাগপাশ লেনদ আম ছিলো বল প্রকাশক টাক প্রয়োজন বল চা যাচ্ছ ভবিষ্যৎ প্রজন্ম ছাপাচ্ছ পড় দেখ প্রয়োজন বোধ করছ' with different Emotion:
#                                                     Text    Label
# 24997  সাহিত্য সাথ টাকা পয়স নাগপাশ লেনদ আম ছিলো বল প...  disgust
# 24998  সাহিত্য সাথ টাকা পয়স নাগপাশ লেনদ আম ছিলো বল প...  sadness
# --------------------
# Similar text 'সুন্দর' with different Emotion:
#          Text  Label
# 577    সুন্দর    joy
# 697    সুন্দর   love
# 1360   সুন্দর   love
# 1965   সুন্দর   love
# 3608   সুন্দর    joy
# 5535   সুন্দর    joy
# 7995   সুন্দর    joy
# 8369   সুন্দর    joy
# 8720   সুন্দর    joy
# 8944   সুন্দর   love
# 10682  সুন্দর    joy
# 11430  সুন্দর    joy
# 14410  সুন্দর    joy
# 15887  সুন্দর  anger
# 16299  সুন্দর    joy
# 16969  সুন্দর    joy
# 18179  সুন্দর    joy
# 18292  সুন্দর    joy
# 27893  সুন্দর    joy
# --------------------
# Similar text 'সুন্দর এক গান' with different Emotion:
#                 Text Label
# 10264  সুন্দর এক গান  love
# 13815  সুন্দর এক গান   joy
# 15447  সুন্দর এক গান   joy
# 18123  সুন্দর এক গান   joy
# --------------------
# Similar text 'সুন্দর এক ব্লগ ছিলো' with different Emotion:
#                      Text Label
# 33    সুন্দর এক ব্লগ ছিলো  love
# 3644  সুন্দর এক ব্লগ ছিলো   joy
# --------------------
# Similar text 'সুন্দর হই' with different Emotion:
#             Text Label
# 488    সুন্দর হই   joy
# 3003   সুন্দর হই  love
# 19099  সুন্দর হই   joy
# --------------------
# Similar text 'স্য ওরাত ভদ্র ফ্যামিলীর খান্দানি চোর বিল গেইট কোম্পানি দরক চুরি টাকা কমা পারবেনা আসল স্য হকিন্নীর —————————' with different Emotion:
#                                                     Text    Label
# 30306  স্য ওরাত ভদ্র ফ্যামিলীর খান্দানি চোর বিল গেইট ...  sadness
# 30367  স্য ওরাত ভদ্র ফ্যামিলীর খান্দানি চোর বিল গেইট ...    anger
# --------------------
# Similar text 'হট্টগোল কর অপরাধ আরো কঠোর শাস্তি হোকদেশ কতদিন চোর হা জিম্মি থাকব' with different Emotion:
#                                                     Text    Label
# 30302  হট্টগোল কর অপরাধ আরো কঠোর শাস্তি হোকদেশ কতদিন ...    anger
# 30314  হট্টগোল কর অপরাধ আরো কঠোর শাস্তি হোকদেশ কতদিন ...  sadness
# --------------------
# ------------------
# Similar text 'ছিলো' with different Emotion:
#       Text Label
# 1408  ছিলো  love
# 3738  ছিলো   joy
# --------------------
# Similar text 'দেহ দিলা মন দিলা' with different Emotion:
#                   Text  Label
# 996   দেহ দিলা মন দিলা  anger
# 1532  দেহ দিলা মন দিলা    joy
# 2689  দেহ দিলা মন দিলা  anger
# --------------------
# Similar text 'পৃথিবীর সবচেয় সুখী মানুষ সৌদি' with different Emotion:
#                                 Text     Label
# 3842  পৃথিবীর সবচেয় সুখী মানুষ সৌদি  surprise
# 4170  পৃথিবীর সবচেয় সুখী মানুষ সৌদি       joy
# --------------------
# Similar text 'ভা' with different Emotion:
#      Text  Label
# 1781   ভা  anger
# 2373   ভা    joy
# 2976   ভা    joy
# 3830   ভা  anger
# --------------------
# Similar text 'ভালো' with different Emotion:
#       Text  Label
# 582   ভালো    joy
# 3150  ভালো    joy
# 3220  ভালো  anger
# 3343  ভালো   love
# --------------------
# Similar text 'ভালো ভা' with different Emotion:
#          Text Label
# 897   ভালো ভা  love
# 3018  ভালো ভা   joy
# --------------------
# Similar text 'ভালো লাগলো' with different Emotion:
#             Text Label
# 693   ভালো লাগলো  love
# 1156  ভালো লাগলো   joy
# 1319  ভালো লাগলো   joy
# 1729  ভালো লাগলো   joy
# --------------------
# Similar text 'সুন্দর' with different Emotion:
#         Text  Label
# 321   সুন্দর  anger
# 733   সুন্দর    joy
# 1403  সুন্দর    joy
# 2495  সুন্দর    joy
# 2615  সুন্দর   love
# 3278  সুন্দর   love
# --------------------
# --------------------
# Similar text '' with different Emotion:
#      Text     Label
# 572        surprise
# 699           anger
# 1392            joy
# 2206            joy
# 2971            joy
# 2988            joy
# --------------------
# Similar text 'এক কথায় অসাধারণ' with different Emotion:
#                  Text Label
# 312  এক কথায় অসাধারণ   joy
# 328  এক কথায় অসাধারণ  love
# --------------------
# Similar text 'নাটক' with different Emotion:
#       Text    Label
# 249   নাটক      joy
# 1601  নাটক  sadness
# --------------------
# Similar text 'ভালো লাগলো আফ্রিদি ভা' with different Emotion:
#                        Text Label
# 2197  ভালো লাগলো আফ্রিদি ভা  love
# 3008  ভালো লাগলো আফ্রিদি ভা   joy
# --------------------
# Similar text 'সুন্দর' with different Emotion:
#         Text Label
# 695   সুন্দর   joy
# 808   সুন্দর   joy
# 1777  সুন্দর  love
# 3420  সুন্দর   joy
# 3687  সুন্দর   joy
# --------------------
# Similar text 'সুন্দর হই' with different Emotion:
#            Text Label
# 1615  সুন্দর হই   joy
# 2815  সুন্দর হই  love
# --------------------

# %%
# #Deleting those rows which are similiar in Text columns and different in Label columns

def remove_conflicting_rows(df):
    """Removes rows with identical 'Text' but different 'Label' values."""

    # Group by 'Text' and get unique labels for each group
    grouped = df.groupby('Text')['Label'].unique()

    # Find texts with more than one unique label
    conflicting_texts = grouped[grouped.apply(len) > 1].index

    # Filter out rows with conflicting texts
    df_filtered = df[~df['Text'].isin(conflicting_texts)]

    return df_filtered

df_train = remove_conflicting_rows(df_train)
df_test = remove_conflicting_rows(df_test)
df_val = remove_conflicting_rows(df_val)

# %%
#Checking
find_similar_rows_different_labels(df_train)
print("------------------")
find_similar_rows_different_labels(df_test)
print("--------------------")
find_similar_rows_different_labels(df_val)
# Out:
# ------------------
# --------------------

# %%
print(df_train.shape)
print(df_test.shape)
print(df_val.shape)
# Out:
# (31051, 2)
# (4309, 2)
# (3941, 2)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def visualize_data(df):
    # Ensure the DataFrame has the required columns
    if 'Text' not in df.columns or 'Label' not in df.columns:
        raise ValueError("DataFrame must contain 'Text' and 'Label' columns")

    # Pie chart for the ratio of data of each class
    label_counts = df['Label'].value_counts()
    plt.figure(figsize=(8, 8))
    plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140)
    plt.title('Ratio of Data for Each Emotion Class')
    plt.show()

# %%
visualize_data(df_train)

# %% [markdown]
# > Machine Learning Models (Logistic Regression, Decision Tree, SVM, Random Forest)

# %%
#Preprocess text
X_train = df_train['Text'].values
y_train = df_train['Label'].values

X_test = df_test['Text'].values
y_test = df_test['Label'].values

X_val = df_val['Text'].values
y_val = df_val['Label'].values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Modelling
from sklearn.model_selection import train_test_split,KFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score
from sklearn.svm import SVC

#For showing confusiong matrix and performance chart
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support

# %%
def train_model(model, data, targets):
    """
    Train a model on the given data and targets.

    Parameters:
    model (sklearn model): The model to be trained.
    data (list of str): The input data.
    targets (list of str): The targets.

    Returns:
    Pipeline: The trained model as a Pipeline object.
    """
    # Create a Pipeline object with a TfidfVectorizer and the given model
    text_clf = Pipeline([('vect',TfidfVectorizer()),
                         ('clf', model)])
    # Fit the model on the data and targets
    text_clf.fit(data, targets)
    return text_clf

# %%
def get_F1(trained_model,X,y):
    """
    Get the F1 score for the given model on the given data and targets.

    Parameters:
    trained_model (sklearn model): The trained model.
    X (list of str): The input data.
    y (list of str): The targets.

    Returns:
    array: The F1 score for each class.
    """
    # Make predictions on the input data using the trained model
    predicted=trained_model.predict(X)
    # Calculate the F1 score for the predictions
    f1=f1_score(y,predicted, average=None)
    # Return the F1 score
    return f1

# %%
#Train the model with the training data
log_reg = train_model(LogisticRegression(solver='liblinear',random_state = 0), X_train, y_train)

# %%
#Make a single prediction
y_pred=log_reg.predict(['খারাপ'])
y_pred
# Out:
# array(['joy'], dtype=object)

# %% [markdown]
# #1. Logistic Regression

# %%
#test the model with the test data
y_pred=log_reg.predict(X_test)

#calculate the accuracy
log_reg_accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: ', log_reg_accuracy,'\n')

#calculate the F1 score
f1_Score = get_F1(log_reg,X_test,y_test)
pd.DataFrame(f1_Score, index=df_train.Label.unique(), columns=['F1 score'])
# Out:
# Accuracy:  0.5061499187746576
#           F1 score
# sadness   0.344720
# anger     0.000000
# joy       0.178218
# love      0.636015
# surprise  0.202166
# fear      0.510441
# disgust   0.150235

# %%
# Predict using the model
y_pred = log_reg.predict(X_test)

# Calculate accuracy
log_reg_accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: ', log_reg_accuracy, '\n')

# Classification Report
print(classification_report(y_test, y_pred))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred, average=None)
labels = sorted(set(y_test))  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy:  0.5061499187746576
#
#               precision    recall  f1-score   support
#
#        anger       0.48      0.27      0.34       823
#      disgust       0.00      0.00      0.00       131
#         fear       0.35      0.12      0.18        75
#          joy       0.52      0.83      0.64      1598
#         love       0.58      0.12      0.20       458
#      sadness       0.50      0.52      0.51      1055
#     surprise       0.36      0.09      0.15       169
#
#     accuracy                           0.51      4309
#    macro avg       0.40      0.28      0.29      4309
# weighted avg       0.49      0.51      0.46      4309
#
#           Precision     Recall   F1 Score
# anger     47.741935  26.974484  34.472050
# disgust    0.000000   0.000000   0.000000
# fear      34.615385  12.000000  17.821782
# joy       51.512801  83.103880  63.601533
# love      58.333333  12.227074  20.216606
# sadness   50.000000  52.132701  51.044084
# surprise  36.363636   9.467456  15.023474

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with the desired style
sns.heatmap(cm, annot=True, fmt="g", cmap="YlGnBu", linewidths=0.5, linecolor='gray', vmin=0, vmax=100)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted label", fontsize=12)
plt.ylabel("True label", fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# #2. Decision Tree

# %%
#Train the model with the training data
DT = train_model(DecisionTreeClassifier(random_state = 0), X_train, y_train)

#test the model with the test data
y_pred=DT.predict(X_test)

#calculate the accuracy
DT_accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: ', DT_accuracy,'\n')

# #calculate the F1 score
# f1_Score = get_F1(DT,X_test,y_test)
# pd.DataFrame(f1_Score, index=df_train.Label.unique(), columns=['F1 score'])
# Out:
# Accuracy:  0.804595033650499

# %%
# Classification Report
print(classification_report(y_test, y_pred))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred, average=None)
labels = sorted(set(y_test))  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.83      0.75      0.79       823
#      disgust       0.49      0.14      0.21       131
#         fear       0.79      0.81      0.80        75
#          joy       0.75      0.93      0.83      1598
#         love       0.92      0.75      0.83       458
#      sadness       0.85      0.78      0.81      1055
#     surprise       0.89      0.64      0.74       169
#
#     accuracy                           0.80      4309
#    macro avg       0.79      0.69      0.72      4309
# weighted avg       0.81      0.80      0.80      4309
#
#           Precision     Recall   F1 Score
# anger     83.445491  75.334143  79.182631
# disgust   48.648649  13.740458  21.428571
# fear      79.220779  81.333333  80.263158
# joy       74.924774  93.491865  83.184855
# love      92.245989  75.327511  82.932692
# sadness   85.254413  77.819905  81.367691
# surprise  89.256198  63.905325  74.482759

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with the desired style
sns.heatmap(cm, annot=True, fmt="g", cmap="YlGnBu", linewidths=0.5, linecolor='gray', vmin=0, vmax=100)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted label", fontsize=12)
plt.ylabel("True label", fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# # 3. SVM

# %%
#Train the model with the training data
SVM = train_model(SVC(random_state = 0), X_train, y_train)

#test the model with the test data
y_pred=SVM.predict(X_test)

#calculate the accuracy
SVM_accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: ', SVM_accuracy,'\n')

#calculate the F1 score
# f1_Score = get_F1(SVM,X_test,y_test)
# pd.DataFrame(f1_Score, index=df_train.Label.unique(), columns=['F1 score'])
# Out:
# Accuracy:  0.6507310280807612

# %%
# Classification Report
print(classification_report(y_test, y_pred))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred, average=None)
labels = sorted(set(y_test))  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.74      0.52      0.61       823
#      disgust       1.00      0.03      0.06       131
#         fear       0.72      0.31      0.43        75
#          joy       0.61      0.91      0.73      1598
#         love       0.85      0.24      0.38       458
#      sadness       0.66      0.71      0.68      1055
#     surprise       0.69      0.21      0.33       169
#
#     accuracy                           0.65      4309
#    macro avg       0.75      0.42      0.46      4309
# weighted avg       0.69      0.65      0.62      4309
#
#            Precision     Recall   F1 Score
# anger      74.430823  51.640340  60.975610
# disgust   100.000000   3.053435   5.925926
# fear       71.875000  30.666667  42.990654
# joy        61.099454  91.113892  73.147450
# love       84.848485  24.454148  37.966102
# sadness    65.903084  70.900474  68.310502
# surprise   69.230769  21.301775  32.579186

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with the desired style
sns.heatmap(cm, annot=True, fmt="g", cmap="YlGnBu", linewidths=0.5, linecolor='gray', vmin=0, vmax=100)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted label", fontsize=12)
plt.ylabel("True label", fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# # Random Forest

# %%
#Train the model with the training data
RF = train_model(RandomForestClassifier(random_state = 0), X_train, y_train)

#test the model with the test data
y_pred=RF.predict(X_test)

#calculate the accuracy
RF_accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: ', RF_accuracy,'\n')

#calculate the F1 score
# f1_Score = get_F1(RF, X_test, y_test)
# pd.DataFrame(f1_Score, index=df_train.Label.unique(), columns=['F1 score'])
# Out:
# Accuracy:  0.8108609886284521

# %%
# Classification Report
print(classification_report(y_test, y_pred))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred, average=None)
labels = sorted(set(y_test))  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.88      0.73      0.80       823
#      disgust       0.74      0.13      0.22       131
#         fear       0.87      0.80      0.83        75
#          joy       0.75      0.95      0.84      1598
#         love       0.93      0.76      0.84       458
#      sadness       0.82      0.80      0.81      1055
#     surprise       0.92      0.64      0.76       169
#
#     accuracy                           0.81      4309
#    macro avg       0.85      0.69      0.73      4309
# weighted avg       0.82      0.81      0.80      4309
#
#           Precision     Recall   F1 Score
# anger     88.313609  72.539490  79.653102
# disgust   73.913043  12.977099  22.077922
# fear      86.956522  80.000000  83.333333
# joy       75.086505  95.056320  83.899475
# love      93.085106  76.419214  83.932854
# sadness   82.226562  79.810427  81.000481
# surprise  92.372881  64.497041  75.958188

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with the desired style
sns.heatmap(cm, annot=True, fmt="g", cmap="YlGnBu", linewidths=0.5, linecolor='gray', vmin=0, vmax=100)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted label", fontsize=12)
plt.ylabel("True label", fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# # All ML Performance Table

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Decision Tree','Support Vector Machine','Random Forest'],
    'Accuracy': [log_reg_accuracy, DT_accuracy, SVM_accuracy, RF_accuracy]})

models.sort_values(by='Accuracy', ascending=False).reset_index().drop(['index'], axis=1)
# Out:
#                     Model  Accuracy
# 0           Random Forest  0.810861
# 1           Decision Tree  0.804595
# 2  Support Vector Machine  0.650731
# 3     Logistic Regression  0.506150

# %% [markdown]
# # Deep Learning Models

# %% [markdown]
# #Emon's CNN Code Without banglaglove

# %%
#Emon's Code
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# Tokenization
vocab_size = 5000  # Increased for better representation
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(df_train['Text'])

# Convert texts to sequences
df_train['text_sequences'] = tokenizer.texts_to_sequences(df_train['Text'])
df_test['text_sequences'] = tokenizer.texts_to_sequences(df_test['Text'])
df_val['text_sequences'] = tokenizer.texts_to_sequences(df_val['Text'])

# Padding
max_length = 100
df_train['padded_sequences'] = list(pad_sequences(df_train['text_sequences'], maxlen=max_length, padding='post'))
df_test['padded_sequences'] = list(pad_sequences(df_test['text_sequences'], maxlen=max_length, padding='post'))
df_val['padded_sequences'] = list(pad_sequences(df_val['text_sequences'], maxlen=max_length, padding='post'))

# Label Encoding
label_encoder = LabelEncoder()
df_train['label_encoded'] = label_encoder.fit_transform(df_train['Label'])
df_test['label_encoded'] = label_encoder.transform(df_test['Label'])
df_val['label_encoded'] = label_encoder.transform(df_val['Label'])

num_classes = len(label_encoder.classes_)

y_train = to_categorical(df_train['label_encoded'], num_classes=num_classes)
y_test = to_categorical(df_test['label_encoded'], num_classes=num_classes)
y_val = to_categorical(df_val['label_encoded'], num_classes=num_classes)

# Convert to NumPy arrays
X_train = np.array(df_train['padded_sequences'].tolist())
X_test = np.array(df_test['padded_sequences'].tolist())
X_val = np.array(df_val['padded_sequences'].tolist())

# CNN Model with Fine-tuning
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length),
    Conv1D(filters=256, kernel_size=5, activation='relu'),  # Increased filters
    GlobalMaxPooling1D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile with learning rate tuning
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),  # Fine-tuned learning rate
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
#Earliy Stopping Function
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,  # Stop training if val_loss doesn't improve for 3 epochs
    restore_best_weights=True
)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=15,  # Increased epochs for better training
    batch_size=32,
    verbose=1,
    callbacks=[early_stopping]  # Added early stopping
)

# Evaluate on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate F1-score table
report = classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)
# f1_df = pd.DataFrame(report).transpose()
# print(f1_df)
# Out:
# Epoch 1/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.3882 - loss: 1.6118 - val_accuracy: 0.6039 - val_loss: 1.1173
# Epoch 2/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5326 - loss: 1.2252 - val_accuracy: 0.6620 - val_loss: 0.9728
# Epoch 3/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6077 - loss: 1.0423 - val_accuracy: 0.7255 - val_loss: 0.8295
# Epoch 4/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6977 - loss: 0.8392 - val_accuracy: 0.7686 - val_loss: 0.7054
# Epoch 5/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7810 - loss: 0.6355 - val_accuracy: 0.8242 - val_loss: 0.6190
# Epoch 6/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8540 - loss: 0.4415 - val_accuracy: 0.8551 - val_loss: 0.5593
# Epoch 7/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9048 - loss: 0.3035 - val_accuracy: 0.8777 - val_loss: 0.5525
# Epoch 8/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9341 - loss: 0.2110 - val_accuracy: 0.8919 - val_loss: 0.5564
# Epoch 9/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9530 - loss: 0.1529 - val_accuracy: 0.8955 - val_loss: 0.5781
# Epoch 10/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9624 - loss: 0.1253 - val_accuracy: 0.8990 - val_loss: 0.6198
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
# Generate classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true_classes, y_pred_classes, average=None)
labels = label_encoder.classes_  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.90      0.82      0.86       823
#      disgust       0.58      0.21      0.31       131
#         fear       0.88      0.84      0.86        75
#          joy       0.91      0.93      0.92      1598
#         love       0.84      0.92      0.88       458
#      sadness       0.86      0.94      0.90      1055
#     surprise       0.85      0.80      0.83       169
#
#     accuracy                           0.88      4309
#    macro avg       0.83      0.78      0.79      4309
# weighted avg       0.88      0.88      0.88      4309
#
#           Precision     Recall   F1 Score
# anger     90.188172  81.530984  85.641353
# disgust   58.333333  21.374046  31.284916
# fear      87.500000  84.000000  85.714286
# joy       91.339066  93.053817  92.188469
# love      83.730159  92.139738  87.733888
# sadness   85.800866  93.933649  89.683258
# surprise  85.443038  79.881657  82.568807

# %%
# Compute confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Convert numerical labels to emotion labels
emotion_labels = label_encoder.classes_

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with emotion labels
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", linewidths=0.5,
            linecolor='gray', xticklabels=emotion_labels, yticklabels=emotion_labels)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("True Label", fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# **CNN With additional reuglarization**

# %%
#Foysals Code
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout, BatchNormalization
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# Tokenization
vocab_size = 5000  # Keeping it optimal
max_length = 100
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")

df_train['Text'] = df_train['Text'].str.lower()  # Normalize case
df_test['Text'] = df_test['Text'].str.lower()
df_val['Text'] = df_val['Text'].str.lower()

tokenizer.fit_on_texts(df_train['Text'])

# Convert texts to sequences
train_sequences = tokenizer.texts_to_sequences(df_train['Text'])
test_sequences = tokenizer.texts_to_sequences(df_test['Text'])
val_sequences = tokenizer.texts_to_sequences(df_val['Text'])

# Padding sequences
X_train = pad_sequences(train_sequences, maxlen=max_length, padding='post')
X_test = pad_sequences(test_sequences, maxlen=max_length, padding='post')
X_val = pad_sequences(val_sequences, maxlen=max_length, padding='post')

# Label Encoding
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(df_train['Label'])
y_test = label_encoder.transform(df_test['Label'])
y_val = label_encoder.transform(df_val['Label'])

num_classes = len(label_encoder.classes_)
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)

# CNN Model with Additional Regularization
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length),
    Conv1D(filters=256, kernel_size=5, activation='relu', padding='same'),
    BatchNormalization(),  # Helps with training stability
    GlobalMaxPooling1D(),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.01)),  # L2 Regularization
    Dropout(0.5),  # Prevent overfitting
    Dense(num_classes, activation='softmax')
])

# Compile with Learning Rate Scheduling
initial_learning_rate = 0.0005
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.9, staircase=True
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Early Stopping to prevent overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,  # Stop training if val_loss doesn't improve for 3 epochs
    restore_best_weights=True
)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    verbose=1,
    callbacks=[early_stopping]  # Added early stopping
)

# Evaluate on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate F1-score table
report = classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)
f1_df = pd.DataFrame(report).transpose()
print(f1_df)


test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3774 - loss: 2.6212 - val_accuracy: 0.6029 - val_loss: 1.2575
# Epoch 2/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5566 - loss: 1.3299 - val_accuracy: 0.7229 - val_loss: 0.9393
# Epoch 3/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6855 - loss: 0.9520 - val_accuracy: 0.8041 - val_loss: 0.7214
# Epoch 4/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8203 - loss: 0.6200 - val_accuracy: 0.8602 - val_loss: 0.5922
# Epoch 5/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9061 - loss: 0.3916 - val_accuracy: 0.8863 - val_loss: 0.5386
# Epoch 6/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9448 - loss: 0.2771 - val_accuracy: 0.8982 - val_loss: 0.5224
# Epoch 7/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9617 - loss: 0.2137 - val_accuracy: 0.9003 - val_loss: 0.5387
# Epoch 8/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9720 - loss: 0.1719 - val_accuracy: 0.9046 - val_loss: 0.5355
# Epoch 9/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9800 - loss: 0.1451 - val_accuracy: 0.9046 - val_loss: 0.5485
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#               precision    recall  f1-score      support
# anger          0.900878  0.872418  0.886420   823.000000
# disgust        0.638298  0.229008  0.337079   131.000000
# fear           0.929577  0.880000  0.904110    75.000000
# joy            0.906122  0.972466  0.938123  1598.000000
# love           0.927765  0.897380  0.912320   458.000000
# sadness        0.907493  0.929858  0.918539  1055.000000
# surprise       0.909677  0.834320  0.870370   169.000000
# accuracy       0.905314  0.905314  0.905314     0.905314
# macro avg      0.874259  0.802207  0.823851  4309.000000
# weighted avg   0.900162  0.905314  0.899188  4309.000000
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9542 - loss: 0.2431
# Test Accuracy: 0.9053

# %%
# Generate classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true_classes, y_pred_classes, average=None)
labels = label_encoder.classes_  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.90      0.87      0.89       823
#      disgust       0.64      0.23      0.34       131
#         fear       0.93      0.88      0.90        75
#          joy       0.91      0.97      0.94      1598
#         love       0.93      0.90      0.91       458
#      sadness       0.91      0.93      0.92      1055
#     surprise       0.91      0.83      0.87       169
#
#     accuracy                           0.91      4309
#    macro avg       0.87      0.80      0.82      4309
# weighted avg       0.90      0.91      0.90      4309
#
#           Precision     Recall   F1 Score
# anger     90.087829  87.241798  88.641975
# disgust   63.829787  22.900763  33.707865
# fear      92.957746  88.000000  90.410959
# joy       90.612245  97.246558  93.812255
# love      92.776524  89.737991  91.231964
# sadness   90.749306  92.985782  91.853933
# surprise  90.967742  83.431953  87.037037

# %%
# Compute confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Convert numerical labels to emotion labels
emotion_labels = label_encoder.classes_

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with emotion labels
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", linewidths=0.5,
            linecolor='gray', xticklabels=emotion_labels, yticklabels=emotion_labels)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("True Label", fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# **Bi-LSTM**

# %%
#Bi-LSTM
import numpy as np
import re
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout

# Tokenization
tokenizer = Tokenizer()
# tokenizer.fit_on_texts(train_data["Text"])
tokenizer.fit_on_texts(df_train["Text"])

# Convert text to sequences
# X_train = tokenizer.texts_to_sequences(train_data["Text"])
X_train = tokenizer.texts_to_sequences(df_train["Text"])
X_test = tokenizer.texts_to_sequences(df_test["Text"])
X_val = tokenizer.texts_to_sequences(df_val["Text"])

# Padding
max_len = max(len(seq) for seq in X_train)
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')
X_val = pad_sequences(X_val, maxlen=max_len, padding='post')

# Label Encoding
label_encoder = LabelEncoder()
# y_train = label_encoder.fit_transform(train_data["Label"])
y_train = label_encoder.fit_transform(df_train["Label"])
y_test = label_encoder.transform(df_test["Label"])
y_val = label_encoder.transform(df_val["Label"])

# Define Bi-LSTM Model
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len),
    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.5),
    Bidirectional(LSTM(64)),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early Stopping Function
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,  # Stop training if val_loss doesn't improve for 3 epochs
    restore_best_weights=True
)


# Train model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=32,callbacks=[early_stopping] )

# Evaluate model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 63s 55ms/step - accuracy: 0.3990 - loss: 1.5906 - val_accuracy: 0.5775 - val_loss: 1.1075
# Epoch 2/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 75s 53ms/step - accuracy: 0.5582 - loss: 1.1696 - val_accuracy: 0.6849 - val_loss: 0.8640
# Epoch 3/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.6891 - loss: 0.8583 - val_accuracy: 0.7846 - val_loss: 0.6953
# Epoch 4/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.8033 - loss: 0.6063 - val_accuracy: 0.8153 - val_loss: 0.6087
# Epoch 5/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 52s 53ms/step - accuracy: 0.8638 - loss: 0.4241 - val_accuracy: 0.8330 - val_loss: 0.5870
# Epoch 6/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 52s 53ms/step - accuracy: 0.8959 - loss: 0.3183 - val_accuracy: 0.8445 - val_loss: 0.5894
# Epoch 7/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 53ms/step - accuracy: 0.9184 - loss: 0.2509 - val_accuracy: 0.8564 - val_loss: 0.6224
# Epoch 8/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9283 - loss: 0.2095 - val_accuracy: 0.8620 - val_loss: 0.6493
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8668 - loss: 0.3808
# Test Accuracy: 0.8434

# %%
# Predict on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate classification report
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)

# Convert report to DataFrame
performance_df = pd.DataFrame(report).transpose()
print(performance_df)

# Extract relevant metrics for plotting
categories = label_encoder.classes_
precision = [report[label]['precision'] * 100 for label in categories]
recall = [report[label]['recall'] * 100 for label in categories]
f1_score = [report[label]['f1-score'] * 100 for label in categories]

# Create performance table similar to your screenshot
performance_table = pd.DataFrame({
    'Category': categories,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score
})
print(performance_table)

# Plot bar chart
bar_width = 0.25
x_indexes = np.arange(len(categories))

plt.figure(figsize=(10, 6))
plt.bar(x_indexes, precision, width=bar_width, label='Precision', color='purple')
plt.bar(x_indexes + bar_width, recall, width=bar_width, label='Recall', color='teal')
plt.bar(x_indexes + 2 * bar_width, f1_score, width=bar_width, label='F1 Score', color='yellow')

# Formatting the plot
plt.xlabel('Emotion Categories')
plt.ylabel('Score (%)')
plt.title('Model Performance Metrics')
plt.xticks(ticks=x_indexes + bar_width, labels=categories, rotation=20)
plt.legend()
plt.show()
# Out:
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step
#               precision    recall  f1-score      support
# anger          0.837550  0.764277  0.799238   823.000000
# disgust        0.491803  0.229008  0.312500   131.000000
# fear           0.852941  0.773333  0.811189    75.000000
# joy            0.853757  0.924280  0.887620  1598.000000
# love           0.843602  0.777293  0.809091   458.000000
# sadness        0.845614  0.913744  0.878360  1055.000000
# surprise       0.875912  0.710059  0.784314   169.000000
# accuracy       0.843351  0.843351  0.843351     0.843351
# macro avg      0.800169  0.727428  0.754616  4309.000000
# weighted avg   0.837439  0.843351  0.837259  4309.000000
#    Category  Precision     Recall   F1 Score
# 0     anger  83.754993  76.427704  79.923761
# 1   disgust  49.180328  22.900763  31.250000
# 2      fear  85.294118  77.333333  81.118881
# 3       joy  85.375723  92.428035  88.762019
# 4      love  84.360190  77.729258  80.909091
# 5   sadness  84.561404  91.374408  87.835991
# 6  surprise  87.591241  71.005917  78.431373

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np
import re
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout
# Tokenization
tokenizer = Tokenizer()
# tokenizer.fit_on_texts(train_data["Text"])
tokenizer.fit_on_texts(df_train["Text"])
# Convert text to sequences
# X_train = tokenizer.texts_to_sequences(train_data["Text"])
X_train = tokenizer.texts_to_sequences(df_train["Text"])
X_test = tokenizer.texts_to_sequences(df_test["Text"])
X_val = tokenizer.texts_to_sequences(df_val["Text"])
# Padding
max_len = max(len(seq) for seq in X_train)
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')
X_val = pad_sequences(X_val, maxlen=max_len, padding='post')
# Label Encoding
label_encoder = LabelEncoder()
# y_train = label_encoder.fit_transform(train_data["Label"])
y_train = label_encoder.fit_transform(df_train["Label"])
y_test = label_encoder.transform(df_test["Label"])
y_val = label_encoder.transform(df_val["Label"])
# implement gru

from tensorflow.keras.layers import GRU

# Define GRU Model
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128
# Early Stopping Function

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,  # Stop training if val_loss doesn't improve for 3 epochs
    restore_best_weights=True
)

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len),
    Bidirectional(GRU(128, return_sequences=True)),  # Using GRU layer
    Dropout(0.5),
    Bidirectional(GRU(64)),  # Using GRU layer
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=32,callbacks=[early_stopping])

# Evaluate model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 56s 53ms/step - accuracy: 0.4019 - loss: 1.5725 - val_accuracy: 0.6361 - val_loss: 1.0190
# Epoch 2/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.5922 - loss: 1.1093 - val_accuracy: 0.7468 - val_loss: 0.7853
# Epoch 3/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 51s 52ms/step - accuracy: 0.7346 - loss: 0.7764 - val_accuracy: 0.7937 - val_loss: 0.6501
# Epoch 4/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.8326 - loss: 0.5239 - val_accuracy: 0.8414 - val_loss: 0.5585
# Epoch 5/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 83s 53ms/step - accuracy: 0.8874 - loss: 0.3501 - val_accuracy: 0.8503 - val_loss: 0.5756
# Epoch 6/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 53ms/step - accuracy: 0.9137 - loss: 0.2686 - val_accuracy: 0.8612 - val_loss: 0.6192
# Epoch 7/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.9287 - loss: 0.2185 - val_accuracy: 0.8721 - val_loss: 0.6321
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8634 - loss: 0.3844
# Test Accuracy: 0.8378

# %%
# Predict on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate classification report
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)

# Convert report to DataFrame
performance_df = pd.DataFrame(report).transpose()
print(performance_df)

# Extract relevant metrics for plotting
categories = label_encoder.classes_
precision = [report[label]['precision'] * 100 for label in categories]
recall = [report[label]['recall'] * 100 for label in categories]
f1_score = [report[label]['f1-score'] * 100 for label in categories]

# Create performance table similar to your screenshot
performance_table = pd.DataFrame({
    'Category': categories,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score
})
print(performance_table)

# Plot bar chart
bar_width = 0.25
x_indexes = np.arange(len(categories))

plt.figure(figsize=(10, 6))
plt.bar(x_indexes, precision, width=bar_width, label='Precision', color='purple')
plt.bar(x_indexes + bar_width, recall, width=bar_width, label='Recall', color='teal')
plt.bar(x_indexes + 2 * bar_width, f1_score, width=bar_width, label='F1 Score', color='yellow')

# Formatting the plot
plt.xlabel('Emotion Categories')
plt.ylabel('Score (%)')
plt.title('Model Performance Metrics')
plt.xticks(ticks=x_indexes + bar_width, labels=categories, rotation=20)
plt.legend()
plt.show()
# Out:
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
#               precision    recall  f1-score      support
# anger          0.797767  0.781288  0.789441   823.000000
# disgust        0.545455  0.229008  0.322581   131.000000
# fear           0.767123  0.746667  0.756757    75.000000
# joy            0.853211  0.931164  0.890485  1598.000000
# love           0.834975  0.740175  0.784722   458.000000
# sadness        0.878903  0.880569  0.879735  1055.000000
# surprise       0.744048  0.739645  0.741840   169.000000
# accuracy       0.837781  0.837781  0.837781     0.837781
# macro avg      0.774497  0.721216  0.737937  4309.000000
# weighted avg   0.831837  0.837781  0.831890  4309.000000
#    Category  Precision     Recall   F1 Score
# 0     anger  79.776675  78.128797  78.944138
# 1   disgust  54.545455  22.900763  32.258065
# 2      fear  76.712329  74.666667  75.675676
# 3       joy  85.321101  93.116395  89.048474
# 4      love  83.497537  74.017467  78.472222
# 5   sadness  87.890255  88.056872  87.973485
# 6  surprise  74.404762  73.964497  74.183976

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# **CNN With Bangla Glove**

# %%
from tensorflow.keras.callbacks import EarlyStopping
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(df_train['Text'])

# Convert texts to sequences
df_train['text_sequences'] = tokenizer.texts_to_sequences(df_train['Text'])
df_test['text_sequences'] = tokenizer.texts_to_sequences(df_test['Text'])
df_val['text_sequences'] = tokenizer.texts_to_sequences(df_val['Text'])

# Padding
max_length = 100
df_train['padded_sequences'] = list(pad_sequences(df_train['text_sequences'], maxlen=max_length, padding='post'))
df_test['padded_sequences'] = list(pad_sequences(df_test['text_sequences'], maxlen=max_length, padding='post'))
df_val['padded_sequences'] = list(pad_sequences(df_val['text_sequences'], maxlen=max_length, padding='post'))

# Label Encoding
label_encoder = LabelEncoder()
df_train['label_encoded'] = label_encoder.fit_transform(df_train['Label'])
df_test['label_encoded'] = label_encoder.transform(df_test['Label'])
df_val['label_encoded'] = label_encoder.transform(df_val['Label'])

num_classes = len(label_encoder.classes_)

y_train = to_categorical(df_train['label_encoded'], num_classes=num_classes)
y_test = to_categorical(df_test['label_encoded'], num_classes=num_classes)
y_val = to_categorical(df_val['label_encoded'], num_classes=num_classes)

# Convert to NumPy arrays
X_train = np.array(df_train['padded_sequences'].tolist())
X_test = np.array(df_test['padded_sequences'].tolist())
X_val = np.array(df_val['padded_sequences'].tolist())


vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128



num_tokens = vocab_size
embedding_dim = 200 #latent factors or features
hits = 0
misses = 0
embeddings_index = {}

from bnlp import BengaliGlove

# Load Bengali GloVe model
bengali_glove = BengaliGlove()

# Get the embedding dimension automatically
sample_word = "ভালো"
embedding_vector = bengali_glove.get_word_vector(sample_word)
embedding_dim = embedding_vector.shape[0]  # Get correct dimension (should be 100)

print(f"Detected embedding dimension: {embedding_dim}")

# Initialize embeddings dictionary
embeddings_index = {word: bengali_glove.get_word_vector(word) for word in bengali_glove.embedding_dict.keys()}

print(f"Found {len(embeddings_index)} Bengali word vectors.")

# Define vocabulary size
num_tokens = vocab_size  # Ensure vocabSize is defined based on your tokenizer

# Initialize embedding matrix with correct dimension
embedding_matrix = np.zeros((num_tokens, embedding_dim))

hits, misses = 0, 0

# Assign word vectors to vocabulary
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None and embedding_vector.shape[0] == embedding_dim:
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1

print(f"Converted {hits} words ({misses} misses)")


#to stop the training when the loss starts to increase
callback = EarlyStopping(
    monitor="val_loss",
    patience=4,
    restore_best_weights=True,
)
# Out:
# Downloading bn_glove.39M.100d.zip:   0%|          | 0/68356215 [00:00<?, ?it/s]
# Extracting: bn_glove.39M.100d.zip:   0%|          | 0/1 [00:00<?, ?it/s]
# Detected embedding dimension: 100
# Found 178153 Bengali word vectors.
# Converted 17978 words (20244 misses)

# %%
# CNN Model with Fine-tuning
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length, weights=[embedding_matrix]),
    Conv1D(filters=256, kernel_size=5, activation='relu'),  # Increased filters
    GlobalMaxPooling1D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile with learning rate tuning
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),  # Fine-tuned learning rate
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=15,  # Increased epochs for better training
    batch_size=32,
    verbose=1,
     callbacks=[callback]
)

# Evaluate on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate F1-score table
report = classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)
f1_df = pd.DataFrame(report).transpose()
print(f1_df)


# Evaluate model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.3783 - loss: 1.6253 - val_accuracy: 0.5638 - val_loss: 1.2113
# Epoch 2/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5035 - loss: 1.3131 - val_accuracy: 0.6453 - val_loss: 0.9883
# Epoch 3/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5866 - loss: 1.1082 - val_accuracy: 0.7087 - val_loss: 0.8377
# Epoch 4/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6671 - loss: 0.8853 - val_accuracy: 0.7856 - val_loss: 0.6889
# Epoch 5/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7601 - loss: 0.6595 - val_accuracy: 0.8338 - val_loss: 0.5746
# Epoch 6/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8447 - loss: 0.4517 - val_accuracy: 0.8731 - val_loss: 0.5014
# Epoch 7/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9008 - loss: 0.2987 - val_accuracy: 0.8906 - val_loss: 0.5141
# Epoch 8/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9403 - loss: 0.1900 - val_accuracy: 0.8990 - val_loss: 0.4907
# Epoch 9/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9559 - loss: 0.1375 - val_accuracy: 0.9033 - val_loss: 0.5072
# Epoch 10/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9666 - loss: 0.1070 - val_accuracy: 0.9069 - val_loss: 0.5727
# Epoch 11/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9726 - loss: 0.0863 - val_accuracy: 0.9102 - val_loss: 0.5986
# Epoch 12/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9796 - loss: 0.0694 - val_accuracy: 0.9142 - val_loss: 0.6965
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#               precision    recall  f1-score      support
# anger          0.875769  0.865128  0.870416   823.000000
# disgust        0.571429  0.183206  0.277457   131.000000
# fear           0.857143  0.880000  0.868421    75.000000
# joy            0.917507  0.967459  0.941822  1598.000000
# love           0.953596  0.897380  0.924634   458.000000
# sadness        0.900461  0.926066  0.913084  1055.000000
# surprise       0.852273  0.887574  0.869565   169.000000
# accuracy       0.901833  0.901833  0.901833     0.901833
# macro avg      0.846882  0.800973  0.809343  4309.000000
# weighted avg   0.895067  0.901833  0.895011  4309.000000
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9495 - loss: 0.1667
# Test Accuracy: 0.9018

# %%
# Generate classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true_classes, y_pred_classes, average=None)
labels = label_encoder.classes_  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.88      0.87      0.87       823
#      disgust       0.57      0.18      0.28       131
#         fear       0.86      0.88      0.87        75
#          joy       0.92      0.97      0.94      1598
#         love       0.95      0.90      0.92       458
#      sadness       0.90      0.93      0.91      1055
#     surprise       0.85      0.89      0.87       169
#
#     accuracy                           0.90      4309
#    macro avg       0.85      0.80      0.81      4309
# weighted avg       0.90      0.90      0.90      4309
#
#           Precision     Recall   F1 Score
# anger     87.576876  86.512758  87.041565
# disgust   57.142857  18.320611  27.745665
# fear      85.714286  88.000000  86.842105
# joy       91.750742  96.745932  94.182150
# love      95.359629  89.737991  92.463442
# sadness   90.046083  92.606635  91.308411
# surprise  85.227273  88.757396  86.956522

# %%
# Compute confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Convert numerical labels to emotion labels
emotion_labels = label_encoder.classes_

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with emotion labels
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", linewidths=0.5,
            linecolor='gray', xticklabels=emotion_labels, yticklabels=emotion_labels)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("True Label", fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# **Bi-LSTM**

# %%
import numpy as np
import re
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import classification_report
import numpy as np
import pandas as pd

# Tokenization
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(train_data["Text"])
vocab_size = 5000  # Increased for better representation
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
# Increased for better representation
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(df_train["Text"])

# Convert text to sequences
# X_train = tokenizer.texts_to_sequences(train_data["Text"])
X_train = tokenizer.texts_to_sequences(df_train["Text"])
X_test = tokenizer.texts_to_sequences(df_test["Text"])
X_val = tokenizer.texts_to_sequences(df_val["Text"])

# Padding
max_len = max(len(seq) for seq in X_train)
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')
X_val = pad_sequences(X_val, maxlen=max_len, padding='post')

# Label Encoding
label_encoder = LabelEncoder()
# y_train = label_encoder.fit_transform(train_data["Label"])
y_train = label_encoder.fit_transform(df_train["Label"])
y_test = label_encoder.transform(df_test["Label"])
y_val = label_encoder.transform(df_val["Label"])



# Define LSTM Model
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128



num_tokens = vocab_size
embedding_dim = 200 #latent factors or features
hits = 0
misses = 0
embeddings_index = {}

from bnlp import BengaliGlove

# Load Bengali GloVe model
bengali_glove = BengaliGlove()

# Get the embedding dimension automatically
sample_word = "গ্রাম"
embedding_vector = bengali_glove.get_word_vector(sample_word)
embedding_dim = embedding_vector.shape[0]  # Get correct dimension (should be 100)

print(f"Detected embedding dimension: {embedding_dim}")

# Initialize embeddings dictionary
embeddings_index = {word: bengali_glove.get_word_vector(word) for word in bengali_glove.embedding_dict.keys()}

print(f"Found {len(embeddings_index)} Bengali word vectors.")

# Define vocabulary size
num_tokens = vocab_size  # Ensure vocabSize is defined based on your tokenizer

# Initialize embedding matrix with correct dimension
embedding_matrix = np.zeros((num_tokens, embedding_dim))

hits, misses = 0, 0

# Assign word vectors to vocabulary
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None and embedding_vector.shape[0] == embedding_dim:
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1

print(f"Converted {hits} words ({misses} misses)")


#to stop the training when the loss starts to increase
callback = EarlyStopping(
    monitor="val_loss",
    patience=4,
    restore_best_weights=True,
)


# Define LSTM Model
vocab_size = len(tokenizer.word_index) + 1
# embedding_dim = 128

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length, weights=[embedding_matrix]),
    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.5),
    Bidirectional(LSTM(64)),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=32,  callbacks=[callback])

# # Evaluate model
# test_loss, test_acc = model.evaluate(X_test, y_test)
# print(f"Test Accuracy: {test_acc:.4f}")

# Predict on test data
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class labels

# Generate classification report
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)

# Convert to DataFrame for better visualization
f1_df = pd.DataFrame(report).transpose()

# Print F1-score table
print(f1_df)
# Out:
# Detected embedding dimension: 100
# Found 178153 Bengali word vectors.
# Converted 17978 words (20244 misses)
# Epoch 1/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 60s 56ms/step - accuracy: 0.4045 - loss: 1.5792 - val_accuracy: 0.5976 - val_loss: 1.1307
# Epoch 2/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 79s 53ms/step - accuracy: 0.5434 - loss: 1.2187 - val_accuracy: 0.6816 - val_loss: 0.9058
# Epoch 3/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 53ms/step - accuracy: 0.6381 - loss: 0.9758 - val_accuracy: 0.7351 - val_loss: 0.7862
# Epoch 4/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 83s 54ms/step - accuracy: 0.7340 - loss: 0.7524 - val_accuracy: 0.7861 - val_loss: 0.6585
# Epoch 5/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.8149 - loss: 0.5536 - val_accuracy: 0.8122 - val_loss: 0.6174
# Epoch 6/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 84s 55ms/step - accuracy: 0.8550 - loss: 0.4396 - val_accuracy: 0.8287 - val_loss: 0.5855
# Epoch 7/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 80s 53ms/step - accuracy: 0.8878 - loss: 0.3490 - val_accuracy: 0.8472 - val_loss: 0.5740
# Epoch 8/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 53ms/step - accuracy: 0.9083 - loss: 0.2834 - val_accuracy: 0.8564 - val_loss: 0.6102
# Epoch 9/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 53ms/step - accuracy: 0.9188 - loss: 0.2469 - val_accuracy: 0.8607 - val_loss: 0.6060
# Epoch 10/10
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 53ms/step - accuracy: 0.9298 - loss: 0.2114 - val_accuracy: 0.8703 - val_loss: 0.6073
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step
#               precision    recall  f1-score      support
# anger          0.813688  0.780073  0.796526   823.000000
# disgust        0.551724  0.244275  0.338624   131.000000
# fear           0.736842  0.746667  0.741722    75.000000
# joy            0.868177  0.935544  0.900602  1598.000000
# love           0.879310  0.779476  0.826389   458.000000
# sadness        0.858824  0.899526  0.878704  1055.000000
# surprise       0.823529  0.745562  0.782609   169.000000
# accuracy       0.848689  0.848689  0.848689     0.848689
# macro avg      0.790299  0.733018  0.752168  4309.000000
# weighted avg   0.843005  0.848689  0.842996  4309.000000

# %%
# Predict on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate classification report
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)

# Convert report to DataFrame
performance_df = pd.DataFrame(report).transpose()
print(performance_df)

# Extract relevant metrics for plotting
categories = label_encoder.classes_
precision = [report[label]['precision'] * 100 for label in categories]
recall = [report[label]['recall'] * 100 for label in categories]
f1_score = [report[label]['f1-score'] * 100 for label in categories]

# Create performance table similar to your screenshot
performance_table = pd.DataFrame({
    'Category': categories,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score
})
print(performance_table)

# Plot bar chart
bar_width = 0.25
x_indexes = np.arange(len(categories))

plt.figure(figsize=(10, 6))
plt.bar(x_indexes, precision, width=bar_width, label='Precision', color='purple')
plt.bar(x_indexes + bar_width, recall, width=bar_width, label='Recall', color='teal')
plt.bar(x_indexes + 2 * bar_width, f1_score, width=bar_width, label='F1 Score', color='yellow')

# Formatting the plot
plt.xlabel('Emotion Categories')
plt.ylabel('Score (%)')
plt.title('Model Performance Metrics')
plt.xticks(ticks=x_indexes + bar_width, labels=categories, rotation=20)
plt.legend()
plt.show()
# Out:
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step
#               precision    recall  f1-score      support
# anger          0.813688  0.780073  0.796526   823.000000
# disgust        0.551724  0.244275  0.338624   131.000000
# fear           0.736842  0.746667  0.741722    75.000000
# joy            0.868177  0.935544  0.900602  1598.000000
# love           0.879310  0.779476  0.826389   458.000000
# sadness        0.858824  0.899526  0.878704  1055.000000
# surprise       0.823529  0.745562  0.782609   169.000000
# accuracy       0.848689  0.848689  0.848689     0.848689
# macro avg      0.790299  0.733018  0.752168  4309.000000
# weighted avg   0.843005  0.848689  0.842996  4309.000000
#    Category  Precision     Recall   F1 Score
# 0     anger  81.368821  78.007290  79.652605
# 1   disgust  55.172414  24.427481  33.862434
# 2      fear  73.684211  74.666667  74.172185
# 3       joy  86.817654  93.554443  90.060241
# 4      love  87.931034  77.947598  82.638889
# 5   sadness  85.882353  89.952607  87.870370
# 6  surprise  82.352941  74.556213  78.260870

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# **Bi-GRU**

# %%
# prompt: import numpy as np
import re
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping

# Tokenization
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(train_data["Text"])
vocab_size = 5000  # Increased for better representation
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(df_train["Text"])
# Convert text to sequences
# X_train = tokenizer.texts_to_sequences(train_data["Text"])
X_train = tokenizer.texts_to_sequences(df_train["Text"])
X_test = tokenizer.texts_to_sequences(df_test["Text"])
X_val = tokenizer.texts_to_sequences(df_val["Text"])
# Padding
max_len = max(len(seq) for seq in X_train)
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')
X_val = pad_sequences(X_val, maxlen=max_len, padding='post')
# Label Encoding
label_encoder = LabelEncoder()
# y_train = label_encoder.fit_transform(train_data["Label"])
y_train = label_encoder.fit_transform(df_train["Label"])
y_test = label_encoder.transform(df_test["Label"])
y_val = label_encoder.transform(df_val["Label"])
# Define
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128



num_tokens = vocab_size
embedding_dim = 200 #latent factors or features
hits = 0
misses = 0
embeddings_index = {}

from bnlp import BengaliGlove

# Load Bengali GloVe model
bengali_glove = BengaliGlove()

# Get the embedding dimension automatically
sample_word = "গ্রাম"
embedding_vector = bengali_glove.get_word_vector(sample_word)
embedding_dim = embedding_vector.shape[0]  # Get correct dimension (should be 100)

print(f"Detected embedding dimension: {embedding_dim}")

# Initialize embeddings dictionary
embeddings_index = {word: bengali_glove.get_word_vector(word) for word in bengali_glove.embedding_dict.keys()}

print(f"Found {len(embeddings_index)} Bengali word vectors.")

# Define vocabulary size
num_tokens = vocab_size  # Ensure vocabSize is defined based on your tokenizer

# Initialize embedding matrix with correct dimension
embedding_matrix = np.zeros((num_tokens, embedding_dim))

hits, misses = 0, 0

# Assign word vectors to vocabulary
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None and embedding_vector.shape[0] == embedding_dim:
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1

print(f"Converted {hits} words ({misses} misses)")


#to stop the training when the loss starts to increase
callback = EarlyStopping(
    monitor="val_loss",
    patience=4,
    restore_best_weights=True,
)

# from tensorflow.keras.layers import GRU

# Define GRU Model
vocab_size = len(tokenizer.word_index) + 1
# embedding_dim = 128

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim,
              input_length=max_len,
              weights=[embedding_matrix]
              ),
    Bidirectional(GRU(128, return_sequences=True)),  # Using GRU layer
    Dropout(0.5),
    Bidirectional(GRU(64)),  # Using GRU layer
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
model.fit(X_train,
          y_train,
          validation_data=(X_val, y_val),
          epochs=15,
          batch_size=32,
          callbacks=[callback]
          )

# Evaluate model
# test_loss, test_acc = model.evaluate(X_test, y_test)
# print(f"Test Accuracy: {test_acc:.4f}")

# Predict on test data
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class labels

# Generate classification report
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)

# Convert to DataFrame for better visualization
f1_df = pd.DataFrame(report).transpose()

# Print F1-score table
print("\nF1-Score Table:\n", f1_df)
# Out:
# Detected embedding dimension: 100
# Found 178153 Bengali word vectors.
# Converted 17978 words (20244 misses)
# Epoch 1/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 55s 52ms/step - accuracy: 0.3815 - loss: 1.6031 - val_accuracy: 0.5633 - val_loss: 1.1536
# Epoch 2/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5110 - loss: 1.3003 - val_accuracy: 0.6275 - val_loss: 1.0439
# Epoch 3/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5541 - loss: 1.1681 - val_accuracy: 0.6359 - val_loss: 0.9995
# Epoch 4/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 81s 51ms/step - accuracy: 0.5882 - loss: 1.0873 - val_accuracy: 0.6658 - val_loss: 0.9369
# Epoch 5/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 83s 52ms/step - accuracy: 0.6151 - loss: 1.0049 - val_accuracy: 0.6823 - val_loss: 0.8830
# Epoch 6/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.6437 - loss: 0.9315 - val_accuracy: 0.7082 - val_loss: 0.8310
# Epoch 7/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 88s 59ms/step - accuracy: 0.6690 - loss: 0.8711 - val_accuracy: 0.7211 - val_loss: 0.8139
# Epoch 8/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 78s 54ms/step - accuracy: 0.6974 - loss: 0.8017 - val_accuracy: 0.7333 - val_loss: 0.7752
# Epoch 9/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 80s 52ms/step - accuracy: 0.7182 - loss: 0.7292 - val_accuracy: 0.7437 - val_loss: 0.7578
# Epoch 10/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 50s 52ms/step - accuracy: 0.7424 - loss: 0.6689 - val_accuracy: 0.7645 - val_loss: 0.7372
# Epoch 11/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.7680 - loss: 0.6074 - val_accuracy: 0.7775 - val_loss: 0.7334
# Epoch 12/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 81s 51ms/step - accuracy: 0.7902 - loss: 0.5569 - val_accuracy: 0.7848 - val_loss: 0.7276
# Epoch 13/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 83s 52ms/step - accuracy: 0.8053 - loss: 0.5185 - val_accuracy: 0.7995 - val_loss: 0.7207
# Epoch 14/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 81s 51ms/step - accuracy: 0.8204 - loss: 0.4679 - val_accuracy: 0.8064 - val_loss: 0.7472
# Epoch 15/15
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 83s 52ms/step - accuracy: 0.8310 - loss: 0.4438 - val_accuracy: 0.8117 - val_loss: 0.7990
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step
#
# F1-Score Table:
#                precision    recall  f1-score      support
# anger          0.799712  0.674362  0.731707   823.000000
# disgust        0.517857  0.221374  0.310160   131.000000
# fear           0.768116  0.706667  0.736111    75.000000
# joy            0.803678  0.929912  0.862199  1598.000000
# love           0.893805  0.661572  0.760351   458.000000
# sadness        0.792955  0.874882  0.831906  1055.000000
# surprise       0.811594  0.662722  0.729642   169.000000
# accuracy       0.803203  0.803203  0.803203     0.803203
# macro avg      0.769674  0.675927  0.708868  4309.000000
# weighted avg   0.800877  0.803203  0.794857  4309.000000

# %%
# Predict on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate classification report
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)

# Convert report to DataFrame
performance_df = pd.DataFrame(report).transpose()
print(performance_df)

# Extract relevant metrics for plotting
categories = label_encoder.classes_
precision = [report[label]['precision'] * 100 for label in categories]
recall = [report[label]['recall'] * 100 for label in categories]
f1_score = [report[label]['f1-score'] * 100 for label in categories]

# Create performance table similar to your screenshot
performance_table = pd.DataFrame({
    'Category': categories,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score
})
print(performance_table)

# Plot bar chart
bar_width = 0.25
x_indexes = np.arange(len(categories))

plt.figure(figsize=(10, 6))
plt.bar(x_indexes, precision, width=bar_width, label='Precision', color='purple')
plt.bar(x_indexes + bar_width, recall, width=bar_width, label='Recall', color='teal')
plt.bar(x_indexes + 2 * bar_width, f1_score, width=bar_width, label='F1 Score', color='yellow')

# Formatting the plot
plt.xlabel('Emotion Categories')
plt.ylabel('Score (%)')
plt.title('Model Performance Metrics')
plt.xticks(ticks=x_indexes + bar_width, labels=categories, rotation=20)
plt.legend()
plt.show()
# Out:
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step
#               precision    recall  f1-score      support
# anger          0.799712  0.674362  0.731707   823.000000
# disgust        0.517857  0.221374  0.310160   131.000000
# fear           0.768116  0.706667  0.736111    75.000000
# joy            0.803678  0.929912  0.862199  1598.000000
# love           0.893805  0.661572  0.760351   458.000000
# sadness        0.792955  0.874882  0.831906  1055.000000
# surprise       0.811594  0.662722  0.729642   169.000000
# accuracy       0.803203  0.803203  0.803203     0.803203
# macro avg      0.769674  0.675927  0.708868  4309.000000
# weighted avg   0.800877  0.803203  0.794857  4309.000000
#    Category  Precision     Recall   F1 Score
# 0     anger  79.971182  67.436209  73.170732
# 1   disgust  51.785714  22.137405  31.016043
# 2      fear  76.811594  70.666667  73.611111
# 3       joy  80.367766  92.991239  86.219901
# 4      love  89.380531  66.157205  76.035132
# 5   sadness  79.295533  87.488152  83.190626
# 6  surprise  81.159420  66.272189  72.964169

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# **CNNN With Addtional Regularizaton**

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping

# Tokenization
# vocab_size = 5000  # Increased for better representation
# tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")

tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(df_train['Text'])

# Convert texts to sequences
df_train['text_sequences'] = tokenizer.texts_to_sequences(df_train['Text'])
df_test['text_sequences'] = tokenizer.texts_to_sequences(df_test['Text'])
df_val['text_sequences'] = tokenizer.texts_to_sequences(df_val['Text'])

# Padding
max_length = 100
df_train['padded_sequences'] = list(pad_sequences(df_train['text_sequences'], maxlen=max_length, padding='post'))
df_test['padded_sequences'] = list(pad_sequences(df_test['text_sequences'], maxlen=max_length, padding='post'))
df_val['padded_sequences'] = list(pad_sequences(df_val['text_sequences'], maxlen=max_length, padding='post'))

# Label Encoding
label_encoder = LabelEncoder()
df_train['label_encoded'] = label_encoder.fit_transform(df_train['Label'])
df_test['label_encoded'] = label_encoder.transform(df_test['Label'])
df_val['label_encoded'] = label_encoder.transform(df_val['Label'])

num_classes = len(label_encoder.classes_)

y_train = to_categorical(df_train['label_encoded'], num_classes=num_classes)
y_test = to_categorical(df_test['label_encoded'], num_classes=num_classes)
y_val = to_categorical(df_val['label_encoded'], num_classes=num_classes)

# Convert to NumPy arrays
X_train = np.array(df_train['padded_sequences'].tolist())
X_test = np.array(df_test['padded_sequences'].tolist())
X_val = np.array(df_val['padded_sequences'].tolist())


vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128



num_tokens = vocab_size
embedding_dim = 200 #latent factors or features
hits = 0
misses = 0
embeddings_index = {}

from bnlp import BengaliGlove

# Load Bengali GloVe model
bengali_glove = BengaliGlove()

# Get the embedding dimension automatically
sample_word = "ভালো"
embedding_vector = bengali_glove.get_word_vector(sample_word)
embedding_dim = embedding_vector.shape[0]  # Get correct dimension (should be 100)

print(f"Detected embedding dimension: {embedding_dim}")

# Initialize embeddings dictionary
embeddings_index = {word: bengali_glove.get_word_vector(word) for word in bengali_glove.embedding_dict.keys()}

print(f"Found {len(embeddings_index)} Bengali word vectors.")

# Define vocabulary size
num_tokens = vocab_size  # Ensure vocabSize is defined based on your tokenizer

# Initialize embedding matrix with correct dimension
embedding_matrix = np.zeros((num_tokens, embedding_dim))

hits, misses = 0, 0

# Assign word vectors to vocabulary
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None and embedding_vector.shape[0] == embedding_dim:
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1

print(f"Converted {hits} words ({misses} misses)")


#to stop the training when the loss starts to increase
callback = EarlyStopping(
    monitor="val_loss",
    patience=4,
    restore_best_weights=True,
)



# CNN Model with Additional Regularization
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length,weights=[embedding_matrix]),
    Conv1D(filters=256, kernel_size=5, activation='relu', padding='same'),
    BatchNormalization(),  # Helps with training stability
    GlobalMaxPooling1D(),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.01)),  # L2 Regularization
    Dropout(0.5),  # Prevent overfitting
    Dense(num_classes, activation='softmax')
])

# Compile with Learning Rate Scheduling
initial_learning_rate = 0.0005
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.9, staircase=True
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


# Early Stopping to prevent overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,  # Stop training if val_loss doesn't improve for 3 epochs
    restore_best_weights=True
)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    verbose=1,
    callbacks=[early_stopping]  # Added early stopping
)

# Evaluate on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate F1-score table
report = classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)
f1_df = pd.DataFrame(report).transpose()
print(f1_df)


test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Detected embedding dimension: 100
# Found 178153 Bengali word vectors.
# Converted 17978 words (20244 misses)
# Epoch 1/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.3143 - loss: 3.9078 - val_accuracy: 0.4867 - val_loss: 2.2303
# Epoch 2/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4173 - loss: 2.2530 - val_accuracy: 0.5428 - val_loss: 1.6058
# Epoch 3/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4636 - loss: 1.7302 - val_accuracy: 0.5762 - val_loss: 1.3062
# Epoch 4/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5018 - loss: 1.4550 - val_accuracy: 0.6275 - val_loss: 1.1286
# Epoch 5/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5427 - loss: 1.2692 - val_accuracy: 0.6549 - val_loss: 0.9797
# Epoch 6/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5841 - loss: 1.1084 - val_accuracy: 0.7110 - val_loss: 0.8759
# Epoch 7/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6327 - loss: 0.9698 - val_accuracy: 0.7638 - val_loss: 0.7824
# Epoch 8/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6850 - loss: 0.8364 - val_accuracy: 0.7957 - val_loss: 0.7295
# Epoch 9/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7399 - loss: 0.7120 - val_accuracy: 0.8371 - val_loss: 0.6985
# Epoch 10/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7909 - loss: 0.6069 - val_accuracy: 0.8531 - val_loss: 0.6912
# Epoch 11/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8263 - loss: 0.5261 - val_accuracy: 0.8769 - val_loss: 0.6485
# Epoch 12/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8632 - loss: 0.4389 - val_accuracy: 0.8924 - val_loss: 0.6656
# Epoch 13/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8924 - loss: 0.3717 - val_accuracy: 0.9013 - val_loss: 0.6354
# Epoch 14/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9132 - loss: 0.3203 - val_accuracy: 0.9056 - val_loss: 0.6765
# Epoch 15/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9295 - loss: 0.2766 - val_accuracy: 0.9087 - val_loss: 0.7119
# Epoch 16/30
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9397 - loss: 0.2487 - val_accuracy: 0.9137 - val_loss: 0.6882
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#               precision    recall  f1-score      support
# anger          0.861410  0.876063  0.868675   823.000000
# disgust        0.441176  0.229008  0.301508   131.000000
# fear           0.821429  0.920000  0.867925    75.000000
# joy            0.950830  0.968085  0.959380  1598.000000
# love           0.954348  0.958515  0.956427   458.000000
# sadness        0.909091  0.919431  0.914232  1055.000000
# surprise       0.843373  0.828402  0.835821   169.000000
# accuracy       0.908796  0.908796  0.908796     0.908796
# macro avg      0.825951  0.814215  0.814852  4309.000000
# weighted avg   0.901945  0.908796  0.904250  4309.000000
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9592 - loss: 0.2608
# Test Accuracy: 0.9088

# %%
# Generate classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))

# Compute precision, recall, f1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true_classes, y_pred_classes, average=None)
labels = label_encoder.classes_  # Ensure correct label order

# Convert to DataFrame
metrics_df = pd.DataFrame({'Precision': precision * 100, 'Recall': recall * 100, 'F1 Score': f1_score * 100}, index=labels)

# Check if DataFrame is populated
print(metrics_df)

# Plot Performance Table (F1 Score, Recall, Precision)
plt.figure(figsize=(10, 6))
metrics_df.plot(kind='bar', colormap='viridis', ax=plt.gca())  # Use `ax=plt.gca()` for correct rendering
plt.ylim(0, 100)  # Ensure bars are visible
plt.title("Model Performance Metrics")
plt.ylabel("Score (%)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.86      0.88      0.87       823
#      disgust       0.44      0.23      0.30       131
#         fear       0.82      0.92      0.87        75
#          joy       0.95      0.97      0.96      1598
#         love       0.95      0.96      0.96       458
#      sadness       0.91      0.92      0.91      1055
#     surprise       0.84      0.83      0.84       169
#
#     accuracy                           0.91      4309
#    macro avg       0.83      0.81      0.81      4309
# weighted avg       0.90      0.91      0.90      4309
#
#           Precision     Recall   F1 Score
# anger     86.140980  87.606318  86.867470
# disgust   44.117647  22.900763  30.150754
# fear      82.142857  92.000000  86.792453
# joy       95.082975  96.808511  95.937984
# love      95.434783  95.851528  95.642702
# sadness   90.909091  91.943128  91.423186
# surprise  84.337349  82.840237  83.582090

# %%
# Compute confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Convert numerical labels to emotion labels
emotion_labels = label_encoder.classes_

# Set figure size
plt.figure(figsize=(6, 5))

# Plot confusion matrix with emotion labels
sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", linewidths=0.5,
            linecolor='gray', xticklabels=emotion_labels, yticklabels=emotion_labels)

# Labels and title
plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("True Label", fontsize=12)

# Show plot
plt.show()
